# %% [markdown]
# # imports

# %%
from os import listdir,mkdir,makedirs
from os.path import isfile, join, isdir,exists
import pandas as pd
import numpy as np
from scipy import stats
import re
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from myplots import roundup, rounddown, find_decimal_fold, percentile_cut_off, rarefaction_calc, rarefaction_plot,draw_correlation_scatter
from matplotlib.ticker import FormatStrFormatter
import cPickle as pickle
from Bio.SeqUtils import GC
import seaborn as sns
import random
from scipy.stats import pearsonr,fisher_exact
from skbio.diversity.alpha import shannon, simpson, berger_parker_d

from pop_organize import get_sample_data, get_sample_with_dfs
from SufficientStatistics import *
from MyFunctionsShani import *
import math
from myplots import roundup, rounddown, find_decimal_fold
from skbio.stats.distance import mantel
from scipy.spatial.distance import braycurtis, pdist, euclidean


from GeneralFeaturePhenotypeInteractions.Feature_phenotype_functions import * 
from TCR_microbiome_interactions.TCR_microbiome_interactions_functions import *
from TCR_microbiome_interactions.TCR_microbiome_interactions_functions2 import *
from SampleLists.SampleFileFunctions import *
from PhenotypicData.PhenotypeGenerationFunctions import *
from CardioProject.CardioFunctions import *
from PredictionPipeline.PredictionFunctions import *
from TCR_feature_generation.SubsamplingFunctions import *

import os
from Utils import cacheOnDisk
from queue.qp import qp,fakeqp
from addloglevels import sethandlers

#ML imports:
from xgboost import XGBClassifier,XGBRegressor
import lightgbm as lgb
from collections import OrderedDict
from sklearn.model_selection import GroupKFold,StratifiedKFold, KFold
import statsmodels.formula.api as sm
from sklearn.linear_model import LogisticRegression, LinearRegression
import shap
from sklearn import metrics, preprocessing
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel,SelectKBest,chi2,mutual_info_classif,f_classif
from sklearn.naive_bayes import GaussianNB

MyPath='/net/mraid08/export/genie/Lab/Personal/ShaniBAF'

with open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/Sample files/BD lists/PNP530','rb') as fp:
    PNP530=pickle.load(fp)
with open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/Sample files/BD lists/Cardio126','rb') as fp:
    Cardio126=pickle.load(fp)
PNP530Cardio126=PNP530+Cardio126

# %%
import time
cdate=str(time.strftime("%d%m%Y"))
cdate
# Out:
# '12112018'

# %% [markdown]
# # correcting (again) TCR features for major phenotypes using regression

# %% [markdown]
# 1. write new module for that
# 2. test this module for age
# 3. compare results to old resuls and see if there is a problem (correcting features which should be corrected)
# 4. if exerything is ok, correct for age, age+gender, age+gender+eGFR
# 5. if #4, repeat major phenotype prediction using the corrected features

# %% [markdown]
# ## test new correction module

# %%
# !python /home/sbenari/workspace/Microbiome/ShaniBA/TCR_feature_generation/FeatureCorrection_byLinReg.py \
/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/Predictions/featureDFs/allTCRfeatures_percShared10__withRels_noT.dat \
-path_to_phenotype_DF /net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/PNP530Cardio126Combined/Phenotypes/PNP530Cardio126_AllInfo_withDummies.xlsx \
-phen_list '["Age","Gender_Male","eGFR by CKD-EPI"]'
# Out:
# stop
# stop
# done1
# done
# done
# main
# ('Xfile: ', '/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/Predictions/featureDFs/allTCRfeatures_percShared10__withRels_noT.dat')
# ('Xdir: ', '/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/Predictions/featureDFs/')
# ('Xname: ', 'allTCRfeatures_percShared10__withRels_noT')
# X Index is already "bd" or no such column exist
# ('phenotypes to correct for are:', [u'Age', u'Gender_Male', u'eGFR by CKD-EPI'])
# correcting allTCRfeatures_percShared10__withRels_noT for Age
# (u'Age series type:', dtype('float64'))
# checking associations between Age and all TCR features:
# number of phenotype unique values is 50 and therefore correlation test is used
# ('number of features to correct is:', 52)
# ('the most significantly associated features are:', ['top1000clonal_aa_1', 'PC2', 'shannon_aa_1', 'shannon_nt_1', 'top1000clonal_nt_1'])
# 0 AA count_0
# 100 DiabetesType1_rel_seq_count
# ('X_Corr shape after correcting all features is', (656, 147))
# checking which features are still associated with Age:
# (u'Age series type:', dtype('float64'))
# checking associations between Age and all TCR features:
# number of phenotype unique values is 50 and therefore correlation test is used
# ('number of features to correct is:', 0)
# ('the most significantly associated features are:', [])
# correcting allTCRfeatures_percShared10__withRels_noT_AgeCorr for Gender_Male
# (u'Gender_Male series type:', dtype('int64'))
# checking associations between Gender_Male and all TCR features:
# number of phenotype unique values is 2 and therefore ttest is used
# ('number of features to correct is:', 46)
# ('the most significantly associated features are:', [u'shannon_nt_0_AgeCorrRes', u'top1000clonal_nt_1_AgeCorrRes', u'top1000clonal_aa_1_AgeCorrRes', u'normSeqNums_per2000_NT_0_AgeCorrRes', u'shannon_aa_1_AgeCorrRes'])
# 0 berger_aa_0
# 100 berger_nt_0_AgeCorrRes
# ('X_Corr shape after correcting all features is', (656, 147))
# checking which features are still associated with Age:
# (u'Age series type:', dtype('float64'))
# checking associations between Age and all TCR features:
# number of phenotype unique values is 50 and therefore correlation test is used
# ('number of features to correct is:', 0)
# ('the most significantly associated features are:', [])
# checking which features are still associated with Gender_Male:
# (u'Gender_Male series type:', dtype('int64'))
# checking associations between Gender_Male and all TCR features:
# number of phenotype unique values is 2 and therefore ttest is used
# ('number of features to correct is:', 0)
# ('the most significantly associated features are:', [])
# correcting allTCRfeatures_percShared10__withRels_noT_AgeCorr_Gender_MaleCorr for eGFR by CKD-EPI
# (u'eGFR by CKD-EPI series type:', dtype('float64'))
# checking associations between eGFR by CKD-EPI and all TCR features:
# number of phenotype unique values is 79 and therefore correlation test is used
# ('number of features to correct is:', 8)
# ('the most significantly associated features are:', [u'mean_nt_per_aa_1_Gender_MaleCorrRes', 'mean_nt_per_aa_0', 'vDeletion_max_0', 'd5Deletion_mean_0', u'vDeletion_std_0_AgeCorrRes'])
# 0 berger_aa_0
# 100 PC3_AgeCorrRes
# ('X_Corr shape after correcting all features is', (656, 147))
# checking which features are still associated with Age:
# (u'Age series type:', dtype('float64'))
# checking associations between Age and all TCR features:
# number of phenotype unique values is 50 and therefore correlation test is used
# ('number of features to correct is:', 0)
# ('the most significantly associated features are:', [])
# checking which features are still associated with Gender_Male:
# (u'Gender_Male series type:', dtype('int64'))
# checking associations between Gender_Male and all TCR features:
# number of phenotype unique values is 2 and therefore ttest is used
# ('number of features to correct is:', 0)
# ('the most significantly associated features are:', [])
# checking which features are still associated with eGFR by CKD-EPI:
# (u'eGFR by CKD-EPI series type:', dtype('float64'))
# checking associations between eGFR by CKD-EPI and all TCR features:
# number of phenotype unique values is 79 and therefore correlation test is used
# ('number of features to correct is:', 0)
# ('the most significantly associated features are:', [])

# %% [markdown]
# ### check age prediction paradox

# %% [markdown]
# #### check dataframes

# %%
f1='/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/Predictions/featureDFs/allTCRfeatures_percShared10__withRels_noT_AgeCorr.dat'
allTCRfeatures_percShared10__withRels_noT_AgeCorr=pd.read_pickle(f1)
allTCRfeatures_percShared10__withRels_noT_AgeCorr.head()
# Out:
#        berger_aa_0  cdr3Length_mean_0  cdr3Length_mean_1  \
# BD
# BD406     0.047619          46.414634          43.849290
# BD228     0.019465          47.004652          43.906318
# BD714     0.108108          45.232720          43.485130
# BD808     0.053691          46.155560          43.812114
# BD144     0.031320          46.254953          43.639412
#
#        count (templates)_max_0  count (templates)_std_0  d3Deletion_mean_0  \
# BD
# BD406                     15.0                 0.565283           3.252313
# BD228                     28.0                 0.904500           3.388731
# BD714                    382.0                 9.150792           3.278937
# BD808                     24.0                 0.745621           3.363263
# BD144                    164.0                 3.190097           3.219682
#
#        d3Deletion_std_0  d5Deletion_mean_0  d5Deletion_mean_1  \
# BD
# BD406          2.687372           3.620269           3.867856
# BD228          2.668487           3.586715           3.747749
# BD714          2.692033           3.757873           3.867758
# BD808          2.723223           3.609260           3.804166
# BD144          2.726473           3.670586           3.756790
#
#        d5Deletion_std_0       ...        top10clonal_nt_1_AgeCorrRes  \
# BD                            ...
# BD406          2.953297       ...                          -0.094733
# BD228          2.967776       ...                          -0.047450
# BD714          3.010800       ...                           0.045553
# BD808          2.991017       ...                           0.003107
# BD144          3.036817       ...                           0.005799
#
#        vDeletion_max_1_AgeCorrRes  vDeletion_mean_1_AgeCorrRes  \
# BD
# BD406                   17.060347                    -0.056378
# BD228                   -3.479143                    -0.026403
# BD714                   -3.940463                    -0.022286
# BD808                    2.059131                    -0.048722
# BD144                    2.828674                    -0.100580
#
#        vDeletion_std_0_AgeCorrRes  DENV_rel_cum_freq(perc)_AgeCorrRes  \
# BD
# BD406                   -0.147469                            0.098861
# BD228                   -0.141230                            2.064314
# BD714                   -0.006745                           -2.124299
# BD808                   -0.101493                            0.192606
# BD144                   -0.115165                           -1.224072
#
#        DENV_rel_seq_count_AgeCorrRes  totalAnnotateSeqs_AgeCorrRes  \
# BD
# BD406                       0.311464                    -21.651816
# BD228                       1.601166                     19.607149
# BD714                      -0.896652                    -62.053844
# BD808                       0.727577                     56.745143
# BD144                      -0.720251                     74.515153
#
#        PC1_AgeCorrRes  PC2_AgeCorrRes  PC3_AgeCorrRes
# BD
# BD406       -0.009961        0.006823        0.027699
# BD228       -0.003222       -0.033301        0.055209
# BD714       -0.003876        0.051476        0.001289
# BD808        0.009281        0.016281       -0.087860
# BD144        0.014334        0.058647       -0.032511
#
# [5 rows x 147 columns]

# %%
allTCRfeatures_percShared10__withRels_noT_AgeCorr.shape
# Out:
# (656, 147)

# %%
allTCRfeatures_percShared10__withRels_noT_AgeCorr.columns.tolist()
# Out:
# ['berger_aa_0',
#  'cdr3Length_mean_0',
#  'cdr3Length_mean_1',
#  'count (templates)_max_0',
#  'count (templates)_std_0',
#  'd3Deletion_mean_0',
#  'd3Deletion_std_0',
#  'd5Deletion_mean_0',
#  'd5Deletion_mean_1',
#  'd5Deletion_std_0',
#  'frequencyCount (%)_max_0',
#  'frequencyCount (%)_mean_0',
#  'gc_content_1',
#  'jDeletion_max_0',
#  'jDeletion_max_1',
#  'jDeletion_mean_0',
#  'jDeletion_std_0',
#  'jDeletion_std_1',
#  'max_nt_per_aa_0',
#  'mean_nt_per_aa_0',
#  'mean_nt_per_aa_1',
#  'n1Insertion_max_0',
#  'n1Insertion_max_1',
#  'n1Insertion_mean_0',
#  'n1Insertion_mean_1',
#  'n1Insertion_std_0',
#  'n2Insertion_max_0',
#  'n2Insertion_max_1',
#  'n2Insertion_mean_0',
#  'n2Insertion_mean_1',
#  'n2Insertion_std_0',
#  'n2Insertion_std_1',
#  'simpson_aa_0',
#  'simpson_nt_0',
#  'vDeletion_max_0',
#  'vDeletion_mean_0',
#  'vDeletion_std_1',
#  u'Allergy_rel_cum_freq(perc)',
#  u'Allergy_rel_seq_count',
#  u'BreastCancer_rel_cum_freq(perc)',
#  u'BreastCancer_rel_seq_count',
#  u'CMV_rel_cum_freq(perc)',
#  u'CMV_rel_seq_count',
#  u'CalcifiedAorticStenosisdisease_rel_cum_freq(perc)',
#  u'CalcifiedAorticStenosisdisease_rel_seq_count',
#  u'Carcinoma_rel_cum_freq(perc)',
#  u'Carcinoma_rel_seq_count',
#  u'Celiacdisease_rel_cum_freq(perc)',
#  u'Celiacdisease_rel_seq_count',
#  u'Colorectalcancer_rel_cum_freq(perc)',
#  u'Colorectalcancer_rel_seq_count',
#  u'DiabetesType1_rel_cum_freq(perc)',
#  u'DiabetesType1_rel_seq_count',
#  u'EBV_rel_cum_freq(perc)',
#  u'EBV_rel_seq_count',
#  u'GraftVsHostDisease_rel_cum_freq(perc)',
#  u'HCV_rel_cum_freq(perc)',
#  u'HCV_rel_seq_count',
#  u'HIV_rel_cum_freq(perc)',
#  u'HIV_rel_seq_count',
#  u'HSV_rel_cum_freq(perc)',
#  u'HTLV_rel_seq_count',
#  u'HomoSapiens_rel_cum_freq(perc)',
#  u'HomoSapiens_rel_seq_count',
#  u'Influenza_rel_cum_freq(perc)',
#  u'Influenza_rel_seq_count',
#  u'LCMV_rel_cum_freq(perc)',
#  u'LCMV_rel_seq_count',
#  u'Leukemia_rel_cum_freq(perc)',
#  u'Lungcancer_rel_cum_freq(perc)',
#  u'Lupus_rel_cum_freq(perc)',
#  u'M.tuberculosis_rel_cum_freq(perc)',
#  u'M.tuberculosis_rel_seq_count',
#  u'Melanoma_rel_cum_freq(perc)',
#  u'Melanoma_rel_seq_count',
#  u'Multiplesclerosis_rel_cum_freq(perc)',
#  u'Multiplesclerosis_rel_seq_count',
#  u'Plasmodiumberghei_rel_cum_freq(perc)',
#  u'RSV_rel_cum_freq(perc)',
#  u'RheumatoidArthritis_rel_cum_freq(perc)',
#  u'RheumatoidArthritis_rel_seq_count',
#  u'SIV_rel_cum_freq(perc)',
#  u'SIV_rel_seq_count',
#  u'WestNilevirus_rel_cum_freq(perc)',
#  u'WestNilevirus_rel_seq_count',
#  u'YellowFeverVirus_rel_cum_freq(perc)',
#  u'YellowFeverVirus_rel_seq_count',
#  u'totalAnnotatefreqs',
#  'PC4',
#  'PC5',
#  'PC6',
#  'PC7',
#  'PC8',
#  'PC9',
#  'PC10',
#  u'AA count_0_AgeCorrRes',
#  u'AA count_1_AgeCorrRes',
#  u'NT count_0_AgeCorrRes',
#  u'NT count_1_AgeCorrRes',
#  u'berger_aa_1_AgeCorrRes',
#  u'berger_nt_0_AgeCorrRes',
#  u'berger_nt_1_AgeCorrRes',
#  u'cdr3Length_max_0_AgeCorrRes',
#  u'cdr3Length_max_1_AgeCorrRes',
#  u'cdr3Length_std_0_AgeCorrRes',
#  u'cdr3Length_std_1_AgeCorrRes',
#  u'count (templates)_max_1_AgeCorrRes',
#  u'count (templates)_mean_0_AgeCorrRes',
#  u'count (templates)_mean_1_AgeCorrRes',
#  u'count (templates)_std_1_AgeCorrRes',
#  u'd3Deletion_mean_1_AgeCorrRes',
#  u'd3Deletion_std_1_AgeCorrRes',
#  u'd5Deletion_std_1_AgeCorrRes',
#  u'frequencyCount (%)_max_1_AgeCorrRes',
#  u'frequencyCount (%)_mean_1_AgeCorrRes',
#  u'frequencyCount (%)_std_0_AgeCorrRes',
#  u'frequencyCount (%)_std_1_AgeCorrRes',
#  u'gc_content_0_AgeCorrRes',
#  u'jDeletion_mean_1_AgeCorrRes',
#  u'max_nt_per_aa_1_AgeCorrRes',
#  u'n1Insertion_std_1_AgeCorrRes',
#  u'normSeqNums_per2000_NT_0_AgeCorrRes',
#  u'normSeqNums_per2000_NT_1_AgeCorrRes',
#  u'normSeqNums_per200_AA_0_AgeCorrRes',
#  u'normSeqNums_per200_AA_1_AgeCorrRes',
#  u'shannon_aa_0_AgeCorrRes',
#  u'shannon_aa_1_AgeCorrRes',
#  u'shannon_nt_0_AgeCorrRes',
#  u'shannon_nt_1_AgeCorrRes',
#  u'simpson_aa_1_AgeCorrRes',
#  u'simpson_nt_1_AgeCorrRes',
#  u'top1000clonal_aa_1_AgeCorrRes',
#  u'top1000clonal_nt_0_AgeCorrRes',
#  u'top1000clonal_nt_1_AgeCorrRes',
#  u'top10clonal_aa_0_AgeCorrRes',
#  u'top10clonal_aa_1_AgeCorrRes',
#  u'top10clonal_nt_0_AgeCorrRes',
#  u'top10clonal_nt_1_AgeCorrRes',
#  u'vDeletion_max_1_AgeCorrRes',
#  u'vDeletion_mean_1_AgeCorrRes',
#  u'vDeletion_std_0_AgeCorrRes',
#  u'DENV_rel_cum_freq(perc)_AgeCorrRes',
#  u'DENV_rel_seq_count_AgeCorrRes',
#  u'totalAnnotateSeqs_AgeCorrRes',
#  u'PC1_AgeCorrRes',
#  u'PC2_AgeCorrRes',
#  u'PC3_AgeCorrRes']

# %%
f2='/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/predictions2/\
TargetDFs/PNP530_majorPhenotypes_contOnly.xlsx'
phenDF=pd.read_excel(f2).set_index('BD')
phenDF.head()
# Out:
#         Age        BMI  Total Cholesterol  eGFR by CKD-EPI  HbA1C  Glucose
# BD
# BD1     NaN  23.437500              195.0              NaN    5.7     97.0
# BD10   45.0  24.655910              206.0             87.0    4.9     99.0
# BD100  57.0  25.925926              156.0             75.0    5.3    101.0
# BD101  64.0  22.944089              165.0             60.0    5.5     95.0
# BD102  40.0  19.174580              204.0             88.0    5.3     90.0

# %%
phenDF.shape
# Out:
# (949, 6)

# %%
phenDF[phenDF['Age'].notnull()].shape
# Out:
# (943, 6)

# %%
for col in allTCRfeatures_percShared10__withRels_noT_AgeCorr.columns:
    r,p=MyPearsonr(phenDF['Age'].loc[allTCRfeatures_percShared10__withRels_noT_AgeCorr.index],
                   allTCRfeatures_percShared10__withRels_noT_AgeCorr[col])
    if p<0.05:
        print col,round(r,2),round(p,6)
# Out:
# /usr/wisdom/python/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
# berger_aa_0 0.09 0.033826
# d3Deletion_mean_0 -0.09 0.038804
# frequencyCount (%)_max_0 0.09 0.03112
# frequencyCount (%)_mean_0 0.1 0.019253
# n1Insertion_mean_0 0.09 0.040428
# SIV_rel_cum_freq(perc) 0.1 0.022353
# SIV_rel_seq_count 0.09 0.044217

# %%
for col in allTCRfeatures_percShared10__withRels_noT_AgeCorr.columns:
    print col
# Out:
# berger_aa_0
# cdr3Length_mean_0
# cdr3Length_mean_1
# count (templates)_max_0
# count (templates)_std_0
# d3Deletion_mean_0
# d3Deletion_std_0
# d5Deletion_mean_0
# d5Deletion_mean_1
# d5Deletion_std_0
# frequencyCount (%)_max_0
# frequencyCount (%)_mean_0
# gc_content_1
# jDeletion_max_0
# jDeletion_max_1
# jDeletion_mean_0
# jDeletion_std_0
# jDeletion_std_1
# max_nt_per_aa_0
# mean_nt_per_aa_0
# mean_nt_per_aa_1
# n1Insertion_max_0
# n1Insertion_max_1
# n1Insertion_mean_0
# n1Insertion_mean_1
# n1Insertion_std_0
# n2Insertion_max_0
# n2Insertion_max_1
# n2Insertion_mean_0
# n2Insertion_mean_1
# n2Insertion_std_0
# n2Insertion_std_1
# simpson_aa_0
# simpson_nt_0
# vDeletion_max_0
# vDeletion_mean_0
# vDeletion_std_1
# Allergy_rel_cum_freq(perc)
# Allergy_rel_seq_count
# BreastCancer_rel_cum_freq(perc)
# BreastCancer_rel_seq_count
# CMV_rel_cum_freq(perc)
# CMV_rel_seq_count
# CalcifiedAorticStenosisdisease_rel_cum_freq(perc)
# CalcifiedAorticStenosisdisease_rel_seq_count
# Carcinoma_rel_cum_freq(perc)
# Carcinoma_rel_seq_count
# Celiacdisease_rel_cum_freq(perc)
# Celiacdisease_rel_seq_count
# Colorectalcancer_rel_cum_freq(perc)
# Colorectalcancer_rel_seq_count
# DiabetesType1_rel_cum_freq(perc)
# DiabetesType1_rel_seq_count
# EBV_rel_cum_freq(perc)
# EBV_rel_seq_count
# GraftVsHostDisease_rel_cum_freq(perc)
# HCV_rel_cum_freq(perc)
# HCV_rel_seq_count
# HIV_rel_cum_freq(perc)
# HIV_rel_seq_count
# HSV_rel_cum_freq(perc)
# HTLV_rel_seq_count
# HomoSapiens_rel_cum_freq(perc)
# HomoSapiens_rel_seq_count
# Influenza_rel_cum_freq(perc)
# Influenza_rel_seq_count
# LCMV_rel_cum_freq(perc)
# LCMV_rel_seq_count
# Leukemia_rel_cum_freq(perc)
# Lungcancer_rel_cum_freq(perc)
# Lupus_rel_cum_freq(perc)
# M.tuberculosis_rel_cum_freq(perc)
# M.tuberculosis_rel_seq_count
# Melanoma_rel_cum_freq(perc)
# Melanoma_rel_seq_count
# Multiplesclerosis_rel_cum_freq(perc)
# Multiplesclerosis_rel_seq_count
# Plasmodiumberghei_rel_cum_freq(perc)
# RSV_rel_cum_freq(perc)
# RheumatoidArthritis_rel_cum_freq(perc)
# RheumatoidArthritis_rel_seq_count
# SIV_rel_cum_freq(perc)
# SIV_rel_seq_count
# WestNilevirus_rel_cum_freq(perc)
# WestNilevirus_rel_seq_count
# YellowFeverVirus_rel_cum_freq(perc)
# YellowFeverVirus_rel_seq_count
# totalAnnotatefreqs
# PC4
# PC5
# PC6
# PC7
# PC8
# PC9
# PC10
# AA count_0_AgeCorrRes
# AA count_1_AgeCorrRes
# NT count_0_AgeCorrRes
# NT count_1_AgeCorrRes
# berger_aa_1_AgeCorrRes
# berger_nt_0_AgeCorrRes
# berger_nt_1_AgeCorrRes
# cdr3Length_max_0_AgeCorrRes
# cdr3Length_max_1_AgeCorrRes
# cdr3Length_std_0_AgeCorrRes
# cdr3Length_std_1_AgeCorrRes
# count (templates)_max_1_AgeCorrRes
# count (templates)_mean_0_AgeCorrRes
# count (templates)_mean_1_AgeCorrRes
# count (templates)_std_1_AgeCorrRes
# d3Deletion_mean_1_AgeCorrRes
# d3Deletion_std_1_AgeCorrRes
# d5Deletion_std_1_AgeCorrRes
# frequencyCount (%)_max_1_AgeCorrRes
# frequencyCount (%)_mean_1_AgeCorrRes
# frequencyCount (%)_std_0_AgeCorrRes
# frequencyCount (%)_std_1_AgeCorrRes
# gc_content_0_AgeCorrRes
# jDeletion_mean_1_AgeCorrRes
# max_nt_per_aa_1_AgeCorrRes
# n1Insertion_std_1_AgeCorrRes
# normSeqNums_per2000_NT_0_AgeCorrRes
# normSeqNums_per2000_NT_1_AgeCorrRes
# normSeqNums_per200_AA_0_AgeCorrRes
# normSeqNums_per200_AA_1_AgeCorrRes
# shannon_aa_0_AgeCorrRes
# shannon_aa_1_AgeCorrRes
# shannon_nt_0_AgeCorrRes
# shannon_nt_1_AgeCorrRes
# simpson_aa_1_AgeCorrRes
# simpson_nt_1_AgeCorrRes
# top1000clonal_aa_1_AgeCorrRes
# top1000clonal_nt_0_AgeCorrRes
# top1000clonal_nt_1_AgeCorrRes
# top10clonal_aa_0_AgeCorrRes
# top10clonal_aa_1_AgeCorrRes
# top10clonal_nt_0_AgeCorrRes
# top10clonal_nt_1_AgeCorrRes
# vDeletion_max_1_AgeCorrRes
# vDeletion_mean_1_AgeCorrRes
# vDeletion_std_0_AgeCorrRes
# DENV_rel_cum_freq(perc)_AgeCorrRes
# DENV_rel_seq_count_AgeCorrRes
# totalAnnotateSeqs_AgeCorrRes
# PC1_AgeCorrRes
# PC2_AgeCorrRes
# PC3_AgeCorrRes

# %% [markdown]
# #### use old prediction functions and see if the problem exist:

# %%
#get dfs:
#phen:
f1='/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/PNP530Cardio126Combined/Phenotypes/\
PNP530Cardio126_AllInfo_withDummies.xlsx'
phenDF=pd.read_excel(f1).set_index('BD')
phenDF=phenDF['Age']

#features:
folder='/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/Predictions/featureDFs/'
X_file_list=['allTCRfeatures_percShared10__withRels_noT_AgeCorr.dat','allTCRfeatures_percShared10__withRels_noT.dat']

#result folder:
resultFolder='%s/TCR_real_data/predictions2/PNP530_majorPhenotypes/oldPredictionTrial/' %MyPath

with open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/Sample files/BD lists/PNP530','rb') as fp:
    PNP530=pickle.load(fp)
# with open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/Sample files/BD lists/Cardio126','rb') as fp:
#     Cardio126=pickle.load(fp)
# PNP530Cardio126=PNP530+Cardio126


model=XGBRegressor
modelName='XGBRegressor'
featureSelectionMethod_list=[None]         
k_list=[10]
task='reg'

for X_file in X_file_list:
    X=pd.read_pickle(folder+X_file).loc[PNP530,:]

    targetDF=phenDF                     
 
    Xname=X_file
    Y=targetDF
    Y=Y.loc[PNP530].dropna()
    X=X.loc[Y.index,:]
    
    print ('X shape: ', X.shape)
    print ('Y shape: ', Y.shape)

    max_depth_list=[3]
    learninglist=[(0.01,1000)]
    gamma_list=[1]
    subsample_list=[0.7]
    reg_alpha_list=[10]
    for learning in learninglist:
        learning_rate=learning[0]
        n_estimators=learning[1]
        
        
        for max_depth in max_depth_list:
            for gamma in gamma_list:
                for reg_alpha in reg_alpha_list:
                    for subsample in subsample_list:
            
                        model_params={'learning_rate': learning_rate, 'n_estimators': n_estimators,
                        'max_depth': max_depth,'num_threads':2,'bagging_fraction':0.5,'bagging_freq':1,
                        'bagging_seed':3,'gamma':gamma,'reg_alpha':reg_alpha,'subsample':subsample}


                        run_old_classification(X,Xname, Y, k_list,model, modelName,model_params,task,
                                           resultFolder,featureSelectionMethod_list)
# Out:
# ('X shape: ', (527, 147))
# ('Y shape: ', (527,))
# ('klist:', [10])
# ('featureSelectionMethod_list:', [None])
# ('klist:', [10])
# ('featureSelectionMethod_list:', [None])
# None
# 0
# no features were selected
# 1
# no features were selected
# 2
# no features were selected
# 3
# no features were selected
# 4
# no features were selected
# 5
# no features were selected
# 6
# no features were selected
# 7
# no features were selected
# 8
# no features were selected
# 9
# no features were selected
# done with CV...
# ********
# ('YName:', u'Age', 'model:', <class 'xgboost.sklearn.XGBRegressor'>, 'k:', 10, 'featureSelectionMethod', 'None')
# ('model params', ',n_estimators:1000,num_threads:2,reg_alpha:10,bagging_seed:3,bagging_freq:1,learning_rate:0.01,bagging_fraction:0.5,max_depth:3,gamma:1,subsample:0.7')
# ********
# ('sum_importances_shape:', (10, 147))
# Prediction round is over
# all predictions are done
# ('X shape: ', (527, 147))
# ('Y shape: ', (527,))
# ('klist:', [10])
# ('featureSelectionMethod_list:', [None])
# ('klist:', [10])
# ('featureSelectionMethod_list:', [None])
# None
# 0
# no features were selected
# 1
# no features were selected
# 2
# no features were selected
# 3
# no features were selected
# 4
# no features were selected
# 5
# no features were selected
# 6
# no features were selected
# 7
# no features were selected
# 8
# no features were selected
# 9
# no features were selected
# done with CV...
# ********
# ('YName:', u'Age', 'model:', <class 'xgboost.sklearn.XGBRegressor'>, 'k:', 10, 'featureSelectionMethod', 'None')
# ('model params', ',n_estimators:1000,num_threads:2,reg_alpha:10,bagging_seed:3,bagging_freq:1,learning_rate:0.01,bagging_fraction:0.5,max_depth:3,gamma:1,subsample:0.7')
# ********
# ('sum_importances_shape:', (10, 147))
# Prediction round is over
# all predictions are done

# %%
folder='%s/TCR_real_data/predictions2/PNP530_majorPhenotypes/oldPredictionTrial/Age' %MyPath
df_folder='%s/resultDFs' %folder

results=concat_summarizing_dfs_excel(df_folder)
results=results.sort_values(by='p_pear')
nTests=len(results) 
FDR=0.1
results=add_corrected_pValues(results,'p_pear',nTests,FDR)
f1='%s/resultSummary_%s.xlsx' %(folder,cdate)
results.to_excel(f1)
# Out:
# number of dfs in directory: 2
# the length of df list is 2

# %% [markdown]
# ### implement Noam's function:

# %%
def compute_linear_regression(X, Y):
    from tqdm import tnrange, tqdm_notebook
    res = pd.DataFrame(index=Y.columns, columns=['Number of samples', 'intercept', 'MSE', 'r2_Score',
                                                 'real-predicted pearson_r', 'real-predicted pearson_p',
                                                 'coefficient of determination'] + [str(c) for c in X.columns])
    residuals = pd.DataFrame(columns=X.index)
    for i in tqdm_notebook(range(Y.shape[1]), desc='LR'):
        y = Y.iloc[:, i].copy()
        xy = pd.concat((X, y), axis=1).dropna()
        y = y.loc[xy.index]
        X_temp = X.loc[xy.index].copy()
 
        regr = LinearRegression()
        regr.fit(X_temp, y)
        y_pred = regr.predict(X_temp)
        res.loc[Y.columns[i], 'Number of samples'] = xy.shape[0]
        for c in range(X.shape[1]):
            res.loc[Y.columns[i], X.columns[c]] = regr.coef_[c]
        res.loc[Y.columns[i], 'intercept'] = regr.intercept_
        res.loc[Y.columns[i], 'MSE'] = metrics.mean_squared_error(y_pred, y)
        res.loc[Y.columns[i], 'r2_Score'] = metrics.r2_score(y_pred, y)
        r, p = pearsonr(y, y_pred)
        res.loc[Y.columns[i], 'real-predicted pearson_r'] = r
        res.loc[Y.columns[i], 'real-predicted pearson_p'] = p
        res.loc[Y.columns[i], 'coefficient of determination'] = regr.score(X_temp, y)
        residuals = pd.concat((residuals, pd.DataFrame(y - y_pred).T))
        
    residuals.columns.name = Y.index.name
    residuals.index.name = Y.columns.name
    return res, residuals

# %%
f1='/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/PNP530Cardio126Combined/Phenotypes/\
PNP530Cardio126_AllInfo_withDummies.xlsx'
phenDF=pd.read_excel(f1).set_index('BD')
AgePNP530=pd.DataFrame(phenDF.loc[PNP530,'Age'])
AgePNP530=AgePNP530.fillna(AgePNP530['Age'].median())

f2='/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/Predictions/featureDFs/allTCRfeatures_percShared10__withRels_noT.dat'
featureDF=pd.read_pickle(f2)
featureDF=featureDF.loc[PNP530,:]
for col in featureDF.columns:
    if 'norm' in col:
        featureDF[col]=featureDF[col].fillna(featureDF[col].median())
    else:
        featureDF[col]=featureDF[col].fillna(0)

X=AgePNP530
Y=featureDF

res, residuals=compute_linear_regression(X, Y)
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %%
res
# Out:
#                                        Number of samples    intercept  \
# AA count_0                                           530      350.059
# AA count_1                                           530      16677.1
# NT count_0                                           530      4206.75
# NT count_1                                           530        17456
# berger_aa_0                                          530    0.0450454
# berger_aa_1                                          530   0.00344796
# berger_nt_0                                          530    0.0211184
# berger_nt_1                                          530   0.00324352
# cdr3Length_max_0                                     530      78.8468
# cdr3Length_max_1                                     530      76.4554
# cdr3Length_mean_0                                    530      45.8846
# cdr3Length_mean_1                                    530      43.6746
# cdr3Length_std_0                                     530      7.58626
# cdr3Length_std_1                                     530      5.45762
# count (templates)_max_0                              530       169.97
# count (templates)_max_1                              530      102.551
# count (templates)_mean_0                             530      1.20513
# count (templates)_mean_1                             530      1.15651
# count (templates)_std_0                              530        2.771
# count (templates)_std_1                              530     0.565142
# d3Deletion_mean_0                                    530      3.36365
# d3Deletion_mean_1                                    530      3.41628
# d3Deletion_std_0                                     530      2.73606
# d3Deletion_std_1                                     530      2.75358
# d5Deletion_mean_0                                    530      3.69827
# d5Deletion_mean_1                                    530       3.8236
# d5Deletion_std_0                                     530      3.01029
# d5Deletion_std_1                                     530      3.06695
# frequencyCount (%)_max_0                             530     0.474751
# frequencyCount (%)_max_1                             530     0.302206
# ...                                                  ...          ...
# Lungcancer_rel_cum_freq(perc)                        530     0.166625
# Lupus_rel_cum_freq(perc)                             530    0.0649302
# M.tuberculosis_rel_cum_freq(perc)                    530     0.610518
# M.tuberculosis_rel_seq_count                         530     0.445193
# Melanoma_rel_cum_freq(perc)                          530      1.48233
# Melanoma_rel_seq_count                               530      1.26848
# Multiplesclerosis_rel_cum_freq(perc)                 530     0.271421
# Multiplesclerosis_rel_seq_count                      530     0.394201
# Plasmodiumberghei_rel_cum_freq(perc)                 530     0.142987
# RSV_rel_cum_freq(perc)                               530     0.128706
# RheumatoidArthritis_rel_cum_freq(perc)               530     0.460018
# RheumatoidArthritis_rel_seq_count                    530     0.514674
# SIV_rel_cum_freq(perc)                               530      0.12811
# SIV_rel_seq_count                                    530     0.212581
# WestNilevirus_rel_cum_freq(perc)                     530     0.218062
# WestNilevirus_rel_seq_count                          530     0.248124
# YellowFeverVirus_rel_cum_freq(perc)                  530      2.53182
# YellowFeverVirus_rel_seq_count                       530      2.64247
# totalAnnotateSeqs                                    530       235.88
# totalAnnotatefreqs                                   530      1.58014
# PC1                                                  530    0.0530278
# PC2                                                  530    0.0503799
# PC3                                                  530    0.0168452
# PC4                                                  530 -0.000613777
# PC5                                                  530    0.0117573
# PC6                                                  530  -0.00313031
# PC7                                                  530  -0.00230408
# PC8                                                  530   0.00204106
# PC9                                                  530   0.00214901
# PC10                                                 530  -0.00805896
#
#                                                 MSE r2_Score  \
# AA count_0                                  14936.7  -23.558
# AA count_1                              3.03976e+07 -19.2762
# NT count_0                              1.95815e+06  -23.301
# NT count_1                              3.38939e+07 -20.2864
# berger_aa_0                               0.0111308 -114.042
# berger_aa_1                              0.00166015 -21.4387
# berger_nt_0                              0.00492445 -65.2164
# berger_nt_1                              0.00161266   -21.68
# cdr3Length_max_0                            4.89665 -57.6289
# cdr3Length_max_1                            12.2549 -46.6266
# cdr3Length_mean_0                          0.261003 -333.107
# cdr3Length_mean_1                         0.0669053 -225.659
# cdr3Length_std_0                          0.0583716 -86.4062
# cdr3Length_std_1                          0.0146361 -28.1601
# count (templates)_max_0                      298979 -456.589
# count (templates)_max_1                      872005 -42.9336
# count (templates)_mean_0                   0.072979 -50.4654
# count (templates)_mean_1                  0.0536475 -14.0149
# count (templates)_std_0                     87.4294 -165.122
# count (templates)_std_1                     78.9046 -22.5958
# d3Deletion_mean_0                         0.0147221 -121.365
# d3Deletion_mean_1                        0.00585266 -50.5835
# d3Deletion_std_0                          0.0018619 -162.227
# d3Deletion_std_1                        0.000751139 -40.2505
# d5Deletion_mean_0                         0.0142639 -355.344
# d5Deletion_mean_1                        0.00384679 -1729.03
# d5Deletion_std_0                         0.00267008  -102367
# d5Deletion_std_1                        0.000760376 -79.4274
# frequencyCount (%)_max_0                    3.01082 -110.307
# frequencyCount (%)_max_1                    10.3681 -24.0953
# ...                                             ...      ...
# Lungcancer_rel_cum_freq(perc)              0.149889  -464.61
# Lupus_rel_cum_freq(perc)                  0.0823706  -1044.8
# M.tuberculosis_rel_cum_freq(perc)           0.78598 -552.837
# M.tuberculosis_rel_seq_count               0.237541  -172573
# Melanoma_rel_cum_freq(perc)                 2.12822 -214.339
# Melanoma_rel_seq_count                     0.609318 -301.648
# Multiplesclerosis_rel_cum_freq(perc)       0.342354 -298.444
# Multiplesclerosis_rel_seq_count            0.345997 -1185.04
# Plasmodiumberghei_rel_cum_freq(perc)      0.0813255 -323.178
# RSV_rel_cum_freq(perc)                    0.0954176  -163214
# RheumatoidArthritis_rel_cum_freq(perc)      2.64616 -431.736
# RheumatoidArthritis_rel_seq_count          0.424455 -331.526
# SIV_rel_cum_freq(perc)                     0.155638 -100.412
# SIV_rel_seq_count                          0.214925 -130.167
# WestNilevirus_rel_cum_freq(perc)           0.112866 -687.716
# WestNilevirus_rel_seq_count                0.133371 -2824.09
# YellowFeverVirus_rel_cum_freq(perc)         4.46752 -2836.98
# YellowFeverVirus_rel_seq_count              1.72557 -5760.48
# totalAnnotateSeqs                           4676.45 -12.4516
# totalAnnotatefreqs                          1.13626 -678.091
# PC1                                     0.000188477 -9.33349
# PC2                                      0.00147261  -6.4465
# PC3                                       0.0017211 -63.7332
# PC4                                      0.00170411 -1860.15
# PC5                                      0.00165283 -136.915
# PC6                                      0.00165029 -2168.61
# PC7                                       0.0017255 -2869.08
# PC8                                      0.00166229 -952.672
# PC9                                      0.00168758 -1092.62
# PC10                                     0.00173884 -318.245
#
#                                        real-predicted pearson_r  \
# AA count_0                                             0.197805
# AA count_1                                             0.216797
# NT count_0                                             0.198807
# NT count_1                                             0.211826
# berger_aa_0                                           0.0928307
# berger_aa_1                                            0.206554
# berger_nt_0                                            0.121973
# berger_nt_1                                            0.205499
# cdr3Length_max_0                                       0.129501
# cdr3Length_max_1                                       0.143405
# cdr3Length_mean_0                                     0.0546271
# cdr3Length_mean_1                                     0.0662763
# cdr3Length_std_0                                       0.106355
# cdr3Length_std_1                                       0.182089
# count (templates)_max_0                               0.0466969
# count (templates)_max_1                                0.149181
# count (templates)_mean_0                               0.138059
# count (templates)_mean_1                               0.249884
# count (templates)_std_0                               0.0773541
# count (templates)_std_1                                0.201637
# d3Deletion_mean_0                                     0.0900334
# d3Deletion_mean_1                                      0.137903
# d3Deletion_std_0                                      0.0780328
# d3Deletion_std_1                                       0.153845
# d5Deletion_mean_0                                     0.0529001
# d5Deletion_mean_1                                     0.0240352
# d5Deletion_std_0                                     0.00312548
# d5Deletion_std_1                                       0.110819
# frequencyCount (%)_max_0                              0.0943617
# frequencyCount (%)_max_1                               0.195758
# ...                                                         ...
# Lungcancer_rel_cum_freq(perc)                         0.0462938
# Lupus_rel_cum_freq(perc)                              0.0309078
# M.tuberculosis_rel_cum_freq(perc)                     0.0424539
# M.tuberculosis_rel_seq_count                         0.00240719
# Melanoma_rel_cum_freq(perc)                           0.0679881
# Melanoma_rel_seq_count                                0.0573872
# Multiplesclerosis_rel_cum_freq(perc)                  0.0576924
# Multiplesclerosis_rel_seq_count                       0.0290246
# Plasmodiumberghei_rel_cum_freq(perc)                  0.0554548
# RSV_rel_cum_freq(perc)                               0.00247525
# RheumatoidArthritis_rel_cum_freq(perc)                0.0480161
# RheumatoidArthritis_rel_seq_count                     0.0547564
# SIV_rel_cum_freq(perc)                                0.0988154
# SIV_rel_seq_count                                     0.0869837
# WestNilevirus_rel_cum_freq(perc)                      0.0380772
# WestNilevirus_rel_seq_count                           0.0188108
# YellowFeverVirus_rel_cum_freq(perc)                    0.018768
# YellowFeverVirus_rel_seq_count                        0.0131733
# totalAnnotateSeqs                                      0.263052
# totalAnnotatefreqs                                    0.0383457
# PC1                                                    0.297042
# PC2                                                    0.344082
# PC3                                                    0.123341
# PC4                                                   0.0231736
# PC5                                                   0.0848447
# PC6                                                   0.0214639
# PC7                                                   0.0186628
# PC8                                                   0.0323648
# PC9                                                   0.0302252
# PC10                                                  0.0558803
#
#                                        real-predicted pearson_p  \
# AA count_0                                          4.46519e-06
# AA count_1                                          4.67209e-07
# NT count_0                                          3.98447e-06
# NT count_1                                          8.60831e-07
# berger_aa_0                                           0.0326229
# berger_aa_1                                         1.62022e-06
# berger_nt_0                                          0.00492504
# berger_nt_1                                         1.83515e-06
# cdr3Length_max_0                                     0.00281845
# cdr3Length_max_1                                     0.00093045
# cdr3Length_mean_0                                      0.209268
# cdr3Length_mean_1                                      0.127542
# cdr3Length_std_0                                      0.0142995
# cdr3Length_std_1                                    2.47117e-05
# count (templates)_max_0                                 0.28323
# count (templates)_max_1                             0.000569787
# count (templates)_mean_0                             0.00144197
# count (templates)_mean_1                            5.47845e-09
# count (templates)_std_0                               0.0751926
# count (templates)_std_1                             2.87978e-06
# d3Deletion_mean_0                                     0.0382618
# d3Deletion_mean_1                                     0.0014601
# d3Deletion_std_0                                      0.0726623
# d3Deletion_std_1                                     0.00037855
# d5Deletion_mean_0                                       0.22405
# d5Deletion_mean_1                                      0.580876
# d5Deletion_std_0                                       0.942774
# d5Deletion_std_1                                      0.0106771
# frequencyCount (%)_max_0                               0.029849
# frequencyCount (%)_max_1                            5.62432e-06
# ...                                                         ...
# Lungcancer_rel_cum_freq(perc)                          0.287412
# Lupus_rel_cum_freq(perc)                               0.477678
# M.tuberculosis_rel_cum_freq(perc)                      0.329315
# M.tuberculosis_rel_seq_count                            0.95591
# Melanoma_rel_cum_freq(perc)                            0.117978
# Melanoma_rel_seq_count                                 0.187129
# Multiplesclerosis_rel_cum_freq(perc)                   0.184791
# Multiplesclerosis_rel_seq_count                        0.504925
# Plasmodiumberghei_rel_cum_freq(perc)                   0.202439
# RSV_rel_cum_freq(perc)                                 0.954665
# RheumatoidArthritis_rel_cum_freq(perc)                 0.269836
# RheumatoidArthritis_rel_seq_count                      0.208191
# SIV_rel_cum_freq(perc)                                0.0228999
# SIV_rel_seq_count                                     0.0453296
# WestNilevirus_rel_cum_freq(perc)                       0.381655
# WestNilevirus_rel_seq_count                            0.665689
# YellowFeverVirus_rel_cum_freq(perc)                    0.666403
# YellowFeverVirus_rel_seq_count                         0.762218
# totalAnnotateSeqs                                   7.73604e-10
# totalAnnotatefreqs                                     0.378305
# PC1                                                 2.94251e-12
# PC2                                                 3.55275e-16
# PC3                                                  0.00445951
# PC4                                                    0.594513
# PC5                                                   0.0509166
# PC6                                                    0.621994
# PC7                                                    0.668161
# PC8                                                    0.457161
# PC9                                                    0.487462
# PC10                                                   0.198992
#
#                                        coefficient of determination  \
# AA count_0                                                0.0391266
# AA count_1                                                0.0470009
# NT count_0                                                0.0395242
# NT count_1                                                0.0448704
# berger_aa_0                                              0.00861755
# berger_aa_1                                               0.0426644
# berger_nt_0                                               0.0148773
# berger_nt_1                                               0.0422298
# cdr3Length_max_0                                          0.0167704
# cdr3Length_max_1                                          0.0205649
# cdr3Length_mean_0                                        0.00298412
# cdr3Length_mean_1                                        0.00439254
# cdr3Length_std_0                                          0.0113114
# cdr3Length_std_1                                          0.0331564
# count (templates)_max_0                                   0.0021806
# count (templates)_max_1                                   0.0222551
# count (templates)_mean_0                                  0.0190602
# count (templates)_mean_1                                   0.062442
# count (templates)_std_0                                  0.00598366
# count (templates)_std_1                                   0.0406574
# d3Deletion_mean_0                                          0.008106
# d3Deletion_mean_1                                         0.0190174
# d3Deletion_std_0                                         0.00608912
# d3Deletion_std_1                                          0.0236683
# d5Deletion_mean_0                                        0.00279842
# d5Deletion_mean_1                                       0.000577692
# d5Deletion_std_0                                        9.76861e-06
# d5Deletion_std_1                                          0.0122809
# frequencyCount (%)_max_0                                 0.00890413
# frequencyCount (%)_max_1                                  0.0383211
# ...                                                             ...
# Lungcancer_rel_cum_freq(perc)                            0.00214312
# Lupus_rel_cum_freq(perc)                                0.000955295
# M.tuberculosis_rel_cum_freq(perc)                        0.00180233
# M.tuberculosis_rel_seq_count                            5.79458e-06
# Melanoma_rel_cum_freq(perc)                              0.00462238
# Melanoma_rel_seq_count                                   0.00329329
# Multiplesclerosis_rel_cum_freq(perc)                     0.00332841
# Multiplesclerosis_rel_seq_count                          0.00084243
# Plasmodiumberghei_rel_cum_freq(perc)                     0.00307524
# RSV_rel_cum_freq(perc)                                  6.12684e-06
# RheumatoidArthritis_rel_cum_freq(perc)                   0.00230555
# RheumatoidArthritis_rel_seq_count                        0.00299827
# SIV_rel_cum_freq(perc)                                   0.00976448
# SIV_rel_seq_count                                        0.00756617
# WestNilevirus_rel_cum_freq(perc)                         0.00144987
# WestNilevirus_rel_seq_count                             0.000353846
# YellowFeverVirus_rel_cum_freq(perc)                     0.000352239
# YellowFeverVirus_rel_seq_count                          0.000173536
# totalAnnotateSeqs                                         0.0691963
# totalAnnotatefreqs                                       0.00147039
# PC1                                                       0.0882341
# PC2                                                        0.118392
# PC3                                                        0.015213
# PC4                                                     0.000537015
# PC5                                                      0.00719863
# PC6                                                     0.000460699
# PC7                                                     0.000348301
# PC8                                                      0.00104748
# PC9                                                     0.000913562
# PC10                                                     0.00312261
#
#                                                 Age
# AA count_0                                 -1.96159
# AA count_1                                 -97.3879
# NT count_0                                 -22.5782
# NT count_1                                 -100.366
# berger_aa_0                             0.000782371
# berger_aa_1                             0.000684152
# berger_nt_0                             0.000685921
# berger_nt_1                             0.000670701
# cdr3Length_max_0                         -0.0229865
# cdr3Length_max_1                         -0.0403468
# cdr3Length_mean_0                         0.0022231
# cdr3Length_mean_1                       -0.00136654
# cdr3Length_std_0                        -0.00205546
# cdr3Length_std_1                        -0.00178196
# count (templates)_max_0                     2.03311
# count (templates)_max_1                     11.2057
# count (templates)_mean_0                 0.00299516
# count (templates)_mean_1                 0.00475436
# count (templates)_std_0                   0.0577024
# count (templates)_std_1                     0.14545
# d3Deletion_mean_0                      -0.000872436
# d3Deletion_mean_1                      -0.000847227
# d3Deletion_std_0                       -0.000268634
# d3Deletion_std_1                       -0.000339409
# d5Deletion_mean_0                       0.000503226
# d5Deletion_mean_1                      -0.000118605
# d5Deletion_std_0                       -1.28457e-05
# d5Deletion_std_1                       -0.000244563
# frequencyCount (%)_max_0                  0.0130815
# frequencyCount (%)_max_1                  0.0511249
# ...                                             ...
# Lungcancer_rel_cum_freq(perc)           -0.00142709
# Lupus_rel_cum_freq(perc)                0.000705896
# M.tuberculosis_rel_cum_freq(perc)       -0.00299635
# M.tuberculosis_rel_seq_count            9.33167e-05
# Melanoma_rel_cum_freq(perc)             -0.00790725
# Melanoma_rel_seq_count                  -0.00356888
# Multiplesclerosis_rel_cum_freq(perc)     0.00268942
# Multiplesclerosis_rel_seq_count          0.00135851
# Plasmodiumberghei_rel_cum_freq(perc)    -0.00125979
# RSV_rel_cum_freq(perc)                  6.08152e-05
# RheumatoidArthritis_rel_cum_freq(perc)   0.00621978
# RheumatoidArthritis_rel_seq_count        0.00284172
# SIV_rel_cum_freq(perc)                   0.00311596
# SIV_rel_seq_count                        0.00321966
# WestNilevirus_rel_cum_freq(perc)        -0.00101822
# WestNilevirus_rel_seq_count            -0.000546503
# YellowFeverVirus_rel_cum_freq(perc)     -0.00315578
# YellowFeverVirus_rel_seq_count           0.00137651
# totalAnnotateSeqs                          -1.48303
# totalAnnotatefreqs                      -0.00325353
# PC1                                    -0.000339691
# PC2                                     -0.00111852
# PC3                                    -0.000410127
# PC4                                     7.61092e-05
# PC5                                    -0.000275351
# PC6                                     6.93693e-05
# PC7                                     6.16722e-05
# PC8                                     -0.00010501
# PC9                                    -9.88049e-05
# PC10                                    0.000185629
#
# [147 rows x 8 columns]

# %%
residuals
# Out:
#                                               BD406        BD228        BD714  \
# AA count_0                               -32.555890    69.711535   -65.557312
# AA count_1                             -2329.842361 -1195.642995 -2318.927709
# NT count_0                              -361.163838   384.755527  -881.197065
# NT count_1                             -2691.149672 -1360.236961 -2546.672990
# berger_aa_0                               -0.048281    -0.050617     0.032550
# berger_aa_1                               -0.035806    -0.022458     0.000244
# berger_nt_0                               -0.059821    -0.036697     0.048693
# berger_nt_1                               -0.035498    -0.021960     0.000152
# cdr3Length_max_0                          -1.352659     1.888788    -3.950307
# cdr3Length_max_1                           7.167142     2.835697    -5.881875
# cdr3Length_mean_0                          0.385572     1.048952    -0.738542
# cdr3Length_mean_1                          0.263528     0.275460    -0.136163
# cdr3Length_std_0                          -0.098432     0.365003     0.057017
# cdr3Length_std_1                           0.099403     0.212268    -0.141610
# count (templates)_max_0                 -287.122490  -207.029870   132.738363
# count (templates)_max_1                 -727.922774  -421.134119   -71.574136
# count (templates)_mean_0                  -0.327486    -0.165023     0.296054
# count (templates)_mean_1                  -0.363489    -0.177863     0.098365
# count (templates)_std_0                   -5.956372    -3.712977     4.129399
# count (templates)_std_1                   -8.607418    -4.352948     1.157223
# d3Deletion_mean_0                         -0.054631     0.052996    -0.050691
# d3Deletion_mean_1                         -0.051414     0.049441    -0.018614
# d3Deletion_std_0                          -0.031223    -0.058972    -0.033547
# d3Deletion_std_1                          -0.016041    -0.031393    -0.009839
# d5Deletion_mean_0                         -0.110714    -0.127662     0.039974
# d5Deletion_mean_1                          0.051970    -0.072051     0.048788
# d5Deletion_std_0                          -0.056155    -0.042100     0.001014
# d5Deletion_std_1                           0.024710    -0.055128     0.021793
# frequencyCount (%)_max_0                  -1.196097    -0.745712     0.945142
# frequencyCount (%)_max_1                  -2.739837    -1.727277     0.068514
# ...                                             ...          ...          ...
# Lungcancer_rel_cum_freq(perc)             -0.073865    -0.120959    -0.110969
# Lupus_rel_cum_freq(perc)                  -0.110813    -0.087519     0.153406
# M.tuberculosis_rel_cum_freq(perc)          0.277549     0.207714    -0.493660
# M.tuberculosis_rel_seq_count               0.396200     0.032591    -0.448832
# Melanoma_rel_cum_freq(perc)               -0.275057     0.215399    -0.682217
# Melanoma_rel_seq_count                    -0.189047     0.288030     0.594842
# Multiplesclerosis_rel_cum_freq(perc)       0.247070     0.003692    -0.376309
# Multiplesclerosis_rel_seq_count            0.364953     0.043096    -0.447183
# Plasmodiumberghei_rel_cum_freq(perc)      -0.061100     0.980850    -0.093855
# RSV_rel_cum_freq(perc)                     0.560645     0.591697    -0.131078
# RheumatoidArthritis_rel_cum_freq(perc)    -0.170999    -0.659051    -0.702589
# RheumatoidArthritis_rel_seq_count          0.148072    -0.605609    -0.625501
# SIV_rel_cum_freq(perc)                     0.362657     0.133354    -0.249632
# SIV_rel_seq_count                          0.425599     0.165159    -0.338148
# WestNilevirus_rel_cum_freq(perc)          -0.151878    -0.185479    -0.178352
# WestNilevirus_rel_seq_count               -0.212602    -0.230636    -0.226811
# YellowFeverVirus_rel_cum_freq(perc)        0.446518     3.709130    -1.917016
# YellowFeverVirus_rel_seq_count            -0.189572     2.121172     0.752120
# totalAnnotateSeqs                        -21.483820    19.576331   -62.042489
# totalAnnotatefreqs                        -0.130695    -0.015363     2.654470
# PC1                                       -0.009921    -0.003229    -0.003873
# PC2                                        0.006754    -0.033230     0.051517
# PC3                                        0.027548     0.055295     0.001325
# PC4                                       -0.025620     0.064191    -0.007744
# PC5                                       -0.002229    -0.003216     0.020329
# PC6                                        0.013769    -0.017761    -0.000231
# PC7                                       -0.004494    -0.046623    -0.024684
# PC8                                       -0.059838     0.011987     0.030629
# PC9                                        0.004743    -0.004301     0.044272
# PC10                                      -0.020743     0.065330    -0.006418
#
#                                               BD808        BD144        BD617  \
# AA count_0                                59.941976    76.557908   -24.826160
# AA count_1                              5368.029617  2457.908597 -2062.212423
# NT count_0                              1002.286321  1199.068331  -373.149658
# NT count_1                              5410.565350  3426.228165 -2239.109020
# berger_aa_0                               -0.011696    -0.041891    -0.053353
# berger_aa_1                               -0.007795    -0.003102    -0.018681
# berger_nt_0                               -0.034635    -0.018020    -0.016326
# berger_nt_1                               -0.008107    -0.002535    -0.018846
# cdr3Length_max_0                           1.750869     2.980734    -1.789402
# cdr3Length_max_1                          -0.406383     2.997084    -2.599448
# cdr3Length_mean_0                          0.213199     0.290361    -0.246573
# cdr3Length_mean_1                          0.173057     0.014020     0.028368
# cdr3Length_std_0                          -0.141229    -0.121828     0.204085
# cdr3Length_std_1                           0.016346    -0.145027     0.040371
# count (templates)_max_0                 -198.831211   -79.162308  -123.493405
# count (templates)_max_1                  -59.899818   106.043014  -402.014154
# count (templates)_mean_0                  -0.080279    -0.028175     0.035267
# count (templates)_mean_1                   0.031082     0.098245    -0.038980
# count (templates)_std_0                   -3.525642    -1.658189    -1.776771
# count (templates)_std_1                   -0.272663     0.342378    -4.023086
# d3Deletion_mean_0                          0.022293    -0.112563     0.047141
# d3Deletion_mean_1                         -0.058562    -0.087785     0.046753
# d3Deletion_std_0                          -0.005848     0.000088    -0.005221
# d3Deletion_std_1                          -0.000491    -0.006421     0.033837
# d5Deletion_mean_0                         -0.102097    -0.045804    -0.002996
# d5Deletion_mean_1                         -0.016345    -0.062536     0.009124
# d5Deletion_std_0                          -0.018936     0.026992    -0.017258
# d5Deletion_std_1                          -0.010425    -0.023251    -0.009640
# frequencyCount (%)_max_0                  -0.740151    -0.408422    -0.299415
# frequencyCount (%)_max_1                  -0.591603    -0.137789    -1.455017
# ...                                             ...          ...          ...
# Lungcancer_rel_cum_freq(perc)             -0.129521    -0.115250     1.829671
# Lupus_rel_cum_freq(perc)                  -0.083283    -0.090342    -0.097401
# M.tuberculosis_rel_cum_freq(perc)         -0.287469    -0.355082    -0.472686
# M.tuberculosis_rel_seq_count              -0.053918    -0.059447    -0.449485
# Melanoma_rel_cum_freq(perc)               -0.541311    -0.754968    -0.153273
# Melanoma_rel_seq_count                     0.005411     0.027313     0.377168
# Multiplesclerosis_rel_cum_freq(perc)       0.148941    -0.368241     0.087528
# Multiplesclerosis_rel_seq_count           -0.035821    -0.443107     0.284048
# Plasmodiumberghei_rel_cum_freq(perc)      -0.110232    -0.097634     0.397626
# RSV_rel_cum_freq(perc)                    -0.130287     0.016672     0.351159
# RheumatoidArthritis_rel_cum_freq(perc)    -0.131444     0.644179    -0.263465
# RheumatoidArthritis_rel_seq_count          0.198843    -0.227871     0.095348
# SIV_rel_cum_freq(perc)                     0.281163     0.054851    -0.271444
# SIV_rel_seq_count                          0.097408     0.449721    -0.360686
# WestNilevirus_rel_cum_freq(perc)          -0.191588    -0.181406    -0.171224
# WestNilevirus_rel_seq_count               -0.233915    -0.228450    -0.222985
# YellowFeverVirus_rel_cum_freq(perc)        0.982241    -0.647404    -0.456007
# YellowFeverVirus_rel_seq_count             0.077644     0.420814     0.257171
# totalAnnotateSeqs                         56.678177    74.508434   -32.661309
# totalAnnotatefreqs                        -0.225309     0.761394    -0.275947
# PC1                                        0.009265     0.014332    -0.005599
# PC2                                        0.016377     0.058700     0.101140
# PC3                                       -0.087731    -0.032453     0.038389
# PC4                                       -0.067659    -0.068384     0.036524
# PC5                                        0.086083    -0.044816    -0.038397
# PC6                                       -0.077608    -0.046442    -0.004877
# PC7                                        0.059783    -0.055379    -0.011921
# PC8                                        0.094318    -0.146283    -0.011513
# PC9                                       -0.072794     0.000259     0.009480
# PC10                                      -0.033004     0.041161    -0.049958
#
#                                               BD143        BD195        BD673  \
# AA count_0                               -68.095008   224.943399  -201.288465
# AA count_1                             -2139.497137  5933.114965 -9166.642995
# NT count_0                              -460.102251  2019.319548 -2428.244473
# NT count_1                             -1935.545050  6060.088669 -9704.236961
# berger_aa_0                                0.138560    -0.067646     0.044963
# berger_aa_1                               -0.005734    -0.030433    -0.022424
# berger_nt_0                               -0.015174    -0.051207    -0.029921
# berger_nt_1                               -0.005838    -0.029529    -0.021983
# cdr3Length_max_0                          -3.628497     2.348517    -1.111212
# cdr3Length_max_1                          -2.317020     3.642633     5.835697
# cdr3Length_mean_0                         -0.402777     0.442831     0.023466
# cdr3Length_mean_1                         -0.415807     0.095604     0.036322
# cdr3Length_std_0                          -0.133761     0.432888    -0.219280
# cdr3Length_std_1                          -0.194034    -0.037755     0.002801
# count (templates)_max_0                 -132.725173  -242.692064  -219.029870
# count (templates)_max_1                 -180.454172  -488.248455  -447.134119
# count (templates)_mean_0                  -0.019560    -0.190056    -0.148514
# count (templates)_mean_1                   0.126558    -0.150522    -0.176046
# count (templates)_std_0                   -2.431809    -4.937011    -3.815551
# count (templates)_std_1                   -0.612429    -5.593135    -4.673321
# d3Deletion_mean_0                         -0.098982     0.054042    -0.355621
# d3Deletion_mean_1                          0.003492     0.024293    -0.119121
# d3Deletion_std_0                           0.021935     0.002180    -0.122219
# d3Deletion_std_1                           0.038036    -0.002146     0.035767
# d5Deletion_mean_0                          0.085644    -0.078756     0.147366
# d5Deletion_mean_1                          0.037018    -0.020303     0.016764
# d5Deletion_std_0                           0.054218    -0.059705     0.026056
# d5Deletion_std_1                           0.015014    -0.006274     0.004737
# frequencyCount (%)_max_0                  -1.160476    -1.040587    -0.641749
# frequencyCount (%)_max_1                  -2.984792    -2.277740    -1.718043
# ...                                             ...          ...          ...
# Lungcancer_rel_cum_freq(perc)             -0.090990    -0.092417    -0.120959
# Lupus_rel_cum_freq(perc)                  -0.102343    -0.101637    -0.087519
# M.tuberculosis_rel_cum_freq(perc)          1.120039    -0.188030    -0.514635
# M.tuberculosis_rel_seq_count               0.493258     0.049955    -0.448179
# Melanoma_rel_cum_freq(perc)                2.080253    -0.271122    -0.304256
# Melanoma_rel_seq_count                     1.750857     0.417100     0.127774
# Multiplesclerosis_rel_cum_freq(perc)      -0.413961    -0.144594    -0.357483
# Multiplesclerosis_rel_seq_count           -0.466202     0.035157    -0.437673
# Plasmodiumberghei_rel_cum_freq(perc)      -0.076218    -0.077478    -0.102673
# RSV_rel_cum_freq(perc)                    -0.131929    -0.131868     1.719436
# RheumatoidArthritis_rel_cum_freq(perc)     0.782084     0.016587     1.191036
# RheumatoidArthritis_rel_seq_count          1.221507    -0.162443     1.958494
# SIV_rel_cum_freq(perc)                    -0.293255    -0.290139    -0.227820
# SIV_rel_seq_count                         -0.383223    -0.380004    -0.315610
# WestNilevirus_rel_cum_freq(perc)          -0.164097    -0.165115     0.739564
# WestNilevirus_rel_seq_count               -0.219160    -0.219706     1.051415
# YellowFeverVirus_rel_cum_freq(perc)        2.874601     1.365764    -0.580752
# YellowFeverVirus_rel_seq_count             1.058158     2.285949    -0.122418
# totalAnnotateSeqs                        -51.280128    41.236846  -110.423669
# totalAnnotatefreqs                        -1.396961    -0.114369     0.222355
# PC1                                       -0.010237     0.008629    -0.024449
# PC2                                        0.006852    -0.018439     0.059717
# PC3                                       -0.023181    -0.011684    -0.022306
# PC4                                       -0.022054     0.016233     0.008103
# PC5                                        0.015370     0.065276     0.002422
# PC6                                        0.037431    -0.007425     0.009191
# PC7                                       -0.008592    -0.033201    -0.000288
# PC8                                        0.011431     0.014481     0.008251
# PC9                                       -0.021307    -0.004170    -0.020956
# PC10                                      -0.062133     0.042880     0.007405
#
#                                               BD401     ...       \
# AA count_0                               -30.789176     ...
# AA count_1                             -3619.685669     ...
# NT count_0                              -592.761087     ...
# NT count_1                             -3678.998620     ...
# berger_aa_0                               -0.032047     ...
# berger_aa_1                               -0.005149     ...
# berger_nt_0                                0.007094     ...
# berger_nt_1                               -0.004689     ...
# cdr3Length_max_0                          -1.410036     ...
# cdr3Length_max_1                           2.311189     ...
# cdr3Length_mean_0                          0.310563     ...
# cdr3Length_mean_1                         -0.007343     ...
# cdr3Length_std_0                           0.010995     ...
# cdr3Length_std_1                           0.160660     ...
# count (templates)_max_0                  -41.599444     ...
# count (templates)_max_1                 -142.459800     ...
# count (templates)_mean_0                   0.009233     ...
# count (templates)_mean_1                   0.043220     ...
# count (templates)_std_0                   -0.428376     ...
# count (templates)_std_1                   -0.521871     ...
# d3Deletion_mean_0                          0.022468     ...
# d3Deletion_mean_1                         -0.002453     ...
# d3Deletion_std_0                          -0.019189     ...
# d3Deletion_std_1                          -0.023974     ...
# d5Deletion_mean_0                         -0.084601     ...
# d5Deletion_mean_1                         -0.028335     ...
# d5Deletion_std_0                          -0.050099     ...
# d5Deletion_std_1                          -0.037755     ...
# frequencyCount (%)_max_0                   0.139214     ...
# frequencyCount (%)_max_1                  -0.380077     ...
# ...                                             ...     ...
# Lungcancer_rel_cum_freq(perc)              0.661227     ...
# Lupus_rel_cum_freq(perc)                  -0.078342     ...
# M.tuberculosis_rel_cum_freq(perc)         -0.553588     ...
# M.tuberculosis_rel_seq_count              -0.446966     ...
# Melanoma_rel_cum_freq(perc)                1.070120     ...
# Melanoma_rel_seq_count                     1.984040     ...
# Multiplesclerosis_rel_cum_freq(perc)      -0.322520     ...
# Multiplesclerosis_rel_seq_count           -0.420013     ...
# Plasmodiumberghei_rel_cum_freq(perc)      -0.119051     ...
# RSV_rel_cum_freq(perc)                    -0.129861     ...
# RheumatoidArthritis_rel_cum_freq(perc)    -0.578194     ...
# RheumatoidArthritis_rel_seq_count         -0.568667     ...
# SIV_rel_cum_freq(perc)                    -0.187313     ...
# SIV_rel_seq_count                         -0.273755     ...
# WestNilevirus_rel_cum_freq(perc)           0.201653     ...
# WestNilevirus_rel_seq_count                0.399202     ...
# YellowFeverVirus_rel_cum_freq(perc)       -2.071495     ...
# YellowFeverVirus_rel_seq_count            -2.031683     ...
# totalAnnotateSeqs                        -50.703003     ...
# totalAnnotatefreqs                        -0.227132     ...
# PC1                                       -0.005110     ...
# PC2                                       -0.026213     ...
# PC3                                        0.006274     ...
# PC4                                        0.040739     ...
# PC5                                       -0.006181     ...
# PC6                                       -0.032960     ...
# PC7                                       -0.003792     ...
# PC8                                       -0.026716     ...
# PC9                                       -0.028857     ...
# PC10                                       0.036209     ...
#
#                                                BD727        BD893       BD842  \
# AA count_0                               -199.326871   -83.250058  -23.173244
# AA count_1                             -10233.255097 -2562.030893  846.193311
# NT count_0                              -2551.666272  -858.822674 -406.979076
# NT count_1                             -10832.870679 -2698.603242  927.664195
# berger_aa_0                                 0.262470    -0.014906   -0.045370
# berger_aa_1                                -0.014013    -0.015058    0.002197
# berger_nt_0                                -0.000946    -0.036124   -0.034704
# berger_nt_1                                -0.013827    -0.014709    0.002687
# cdr3Length_max_0                           -2.088226     0.865801   -1.180172
# cdr3Length_max_1                            2.876044     2.795350    2.714657
# cdr3Length_mean_0                           0.682736    -0.277118    0.075770
# cdr3Length_mean_1                           0.570448     0.085962    0.225573
# cdr3Length_std_0                           -0.455498    -0.169971   -0.051502
# cdr3Length_std_1                           -0.017706    -0.091708    0.053378
# count (templates)_max_0                  -187.062979  -212.996760 -205.930540
# count (templates)_max_1                  -422.339835  -312.928402   60.483032
# count (templates)_mean_0                   -0.020455    -0.091032   -0.132372
# count (templates)_mean_1                   -0.005940    -0.042600   -0.051766
# count (templates)_std_0                    -2.834180    -3.655895   -3.668650
# count (templates)_std_1                    -3.784412    -3.031595    0.073846
# d3Deletion_mean_0                           0.046456    -0.169311   -0.061086
# d3Deletion_mean_1                           0.076497    -0.072220   -0.024357
# d3Deletion_std_0                            0.039235     0.005526   -0.080818
# d3Deletion_std_1                           -0.036913    -0.001663   -0.029658
# d5Deletion_mean_0                           0.003802     0.050100    0.027674
# d5Deletion_mean_1                          -0.085160    -0.078892    0.042314
# d5Deletion_std_0                            0.025314    -0.012630    0.030017
# d5Deletion_std_1                            0.000040    -0.018543    0.031742
# frequencyCount (%)_max_0                    0.003145    -0.768453   -0.753565
# frequencyCount (%)_max_1                   -1.079741    -1.121073    0.348598
# ...                                              ...          ...         ...
# Lungcancer_rel_cum_freq(perc)              -0.119531    -0.122386   -0.125240
# Lupus_rel_cum_freq(perc)                   -0.088225    -0.086813   -0.085401
# M.tuberculosis_rel_cum_freq(perc)          -0.511639     0.292699   -0.173882
# M.tuberculosis_rel_seq_count               -0.448272     0.205509    0.035193
# Melanoma_rel_cum_freq(perc)                 0.353650    -1.237207   -0.203794
# Melanoma_rel_seq_count                      2.182625    -1.157846   -0.681892
# Multiplesclerosis_rel_cum_freq(perc)       -0.360172     0.050372    0.000328
# Multiplesclerosis_rel_seq_count            -0.439032     0.217280    0.049494
# Plasmodiumberghei_rel_cum_freq(perc)       -0.101414    -0.103933   -0.106453
# RSV_rel_cum_freq(perc)                     -0.130713    -0.130591   -0.130470
# RheumatoidArthritis_rel_cum_freq(perc)     -0.665271    -0.652831    0.408835
# RheumatoidArthritis_rel_seq_count          -0.608451    -0.602767    0.369100
# SIV_rel_cum_freq(perc)                     -0.230936     0.180461   -0.218472
# SIV_rel_seq_count                          -0.318830     0.341204   -0.305951
# WestNilevirus_rel_cum_freq(perc)           -0.184461    -0.186497    0.161209
# WestNilevirus_rel_seq_count                -0.230090    -0.231183    0.250816
# YellowFeverVirus_rel_cum_freq(perc)        -2.427683    -1.218499    4.904280
# YellowFeverVirus_rel_seq_count             -2.687897    -1.377954    2.631619
# totalAnnotateSeqs                        -126.940643   -36.906694   14.127254
# totalAnnotatefreqs                          0.837579    -0.103824   -0.239829
# PC1                                        -0.026848    -0.000709   -0.005020
# PC2                                         0.021621     0.096956   -0.032811
# PC3                                         0.008721    -0.027048    0.074534
# PC4                                         0.020398    -0.017597   -0.000511
# PC5                                        -0.007044    -0.004722   -0.034956
# PC6                                         0.012394     0.031944    0.058582
# PC7                                         0.027979     0.008869    0.019907
# PC8                                        -0.015542     0.049003   -0.024323
# PC9                                         0.015184     0.024329    0.006028
# PC10                                       -0.002525     0.024623   -0.041558
#
#                                               BD397        BD839         BD84  \
# AA count_0                               -79.595719   -14.864567   -53.480499
# AA count_1                             -1877.539811 -1817.824525  1985.296495
# NT count_0                              -979.618864  -729.571457  -262.353468
# NT count_1                             -1829.306709 -2142.742739  2195.594447
# berger_aa_0                                0.000255     0.125683    -0.058842
# berger_aa_1                               -0.014405    -0.014208    -0.005451
# berger_nt_0                                0.061759    -0.015637     0.056376
# berger_nt_1                               -0.014079    -0.013509    -0.005404
# cdr3Length_max_0                           2.072679     2.233585     0.003720
# cdr3Length_max_1                          -2.841528     0.440899    -5.962569
# cdr3Length_mean_0                         -0.292332     0.408304    -0.846841
# cdr3Length_mean_1                         -0.292248    -0.042693    -0.064922
# cdr3Length_std_0                           0.008229     0.467178    -0.283458
# cdr3Length_std_1                          -0.059397     0.077154    -0.165883
# count (templates)_max_0                   71.705253  -132.526515   248.804582
# count (templates)_max_1                 -320.779853  -321.219871     1.837297
# count (templates)_mean_0                  -0.065040     0.113534     0.228596
# count (templates)_mean_1                  -0.108134    -0.012558     0.104902
# count (templates)_std_0                    1.622689    -1.112964     5.042319
# count (templates)_std_1                   -2.911508    -3.058125     0.900650
# d3Deletion_mean_0                          0.085186     0.130166     0.043989
# d3Deletion_mean_1                          0.097462     0.139493    -0.001380
# d3Deletion_std_0                           0.011674    -0.061793     0.000306
# d3Deletion_std_1                           0.002223     0.021415    -0.012611
# d5Deletion_mean_0                          0.016107     0.009863    -0.072312
# d5Deletion_mean_1                         -0.022176     0.101477    -0.080156
# d5Deletion_std_0                          -0.061285     0.002246    -0.000909
# d5Deletion_std_1                           0.023703     0.007950     0.011537
# frequencyCount (%)_max_0                   0.867961    -0.351310    -0.940941
# frequencyCount (%)_max_1                  -1.018491    -0.995390    -2.175098
# ...                                             ...          ...          ...
# Lungcancer_rel_cum_freq(perc)             -0.109542     0.429108     0.247057
# Lupus_rel_cum_freq(perc)                  -0.093166    -0.098107    -0.091048
# M.tuberculosis_rel_cum_freq(perc)          0.274503     0.058970    -0.138773
# M.tuberculosis_rel_seq_count               0.071908     0.331672     0.029824
# Melanoma_rel_cum_freq(perc)               -0.400875    -0.053371    -0.107122
# Melanoma_rel_seq_count                    -0.604893    -0.319494    -0.179495
# Multiplesclerosis_rel_cum_freq(perc)      -0.378998    -0.397824    -0.370930
# Multiplesclerosis_rel_seq_count           -0.448541    -0.458051    -0.444466
# Plasmodiumberghei_rel_cum_freq(perc)      -0.092595     0.973543     0.264506
# RSV_rel_cum_freq(perc)                    -0.131139    -0.131564    -0.130956
# RheumatoidArthritis_rel_cum_freq(perc)    -0.326226    -0.752348     0.392492
# RheumatoidArthritis_rel_seq_count         -0.107509    -0.648235     0.337120
# SIV_rel_cum_freq(perc)                    -0.252748     0.782760    -0.243400
# SIV_rel_seq_count                         -0.341368     0.417345    -0.331709
# WestNilevirus_rel_cum_freq(perc)          -0.177333    -0.170206     0.541373
# WestNilevirus_rel_seq_count               -0.226264    -0.222439     0.250565
# YellowFeverVirus_rel_cum_freq(perc)       -0.110092    -1.854842    -0.971538
# YellowFeverVirus_rel_seq_count             0.427467    -1.925918    -0.779527
# totalAnnotateSeqs                         15.440537   -38.178283    27.991460
# totalAnnotatefreqs                         0.063579    -0.372546    -1.448174
# PC1                                        0.004763    -0.002255     0.008044
# PC2                                        0.001501    -0.034379     0.048819
# PC3                                        0.031901     0.006267    -0.032790
# PC4                                        0.015199     0.023803    -0.032405
# PC5                                        0.037031    -0.042519    -0.013677
# PC6                                       -0.000409    -0.021556     0.002023
# PC7                                       -0.028828    -0.033346    -0.065917
# PC8                                        0.004859    -0.003608     0.021861
# PC9                                       -0.001899    -0.004072    -0.009135
# PC10                                       0.063388    -0.011954     0.087588
#
#                                               BD894        BD390       BD437  \
# AA count_0                               -71.211651   -28.557312  -52.095008
# AA count_1                             -3027.418791 -4270.927709 -456.497137
# NT count_0                              -755.400875  -541.197065  -83.102251
# NT count_1                             -3234.969524 -4438.672990 -291.545050
# berger_aa_0                               -0.037865    -0.057701   -0.072686
# berger_aa_1                                0.096396    -0.014878   -0.026400
# berger_nt_0                                0.421486     0.003270   -0.049511
# berger_nt_1                                0.096066    -0.014573   -0.026686
# cdr3Length_max_0                           0.842815     2.049693   -0.628497
# cdr3Length_max_1                           5.755004     3.118125   -2.317020
# cdr3Length_mean_0                          0.321277     0.812221   -1.243246
# cdr3Length_mean_1                          0.109406     0.389693   -0.737492
# cdr3Length_std_0                          -0.059909     0.114824   -0.244282
# cdr3Length_std_1                           0.050704     0.281210   -0.126966
# count (templates)_max_0                 2782.036350   -65.261637 -251.725173
# count (templates)_max_1                 1727.277315  -364.574136 -525.454172
# count (templates)_mean_0                   1.050004    -0.030021   -0.248056
# count (templates)_mean_1                   0.318704    -0.045430   -0.215832
# count (templates)_std_0                   52.695767    -1.196675   -5.063921
# count (templates)_std_1                   16.759463    -3.828190   -5.935785
# d3Deletion_mean_0                         -0.033947    -0.061764   -0.176997
# d3Deletion_mean_1                         -0.033500     0.002353    0.016132
# d3Deletion_std_0                          -0.051388    -0.063170    0.043636
# d3Deletion_std_1                           0.008039    -0.003702    0.040190
# d5Deletion_mean_0                         -0.061604     0.006697    0.419914
# d5Deletion_mean_1                         -0.022714     0.019325    0.155253
# d5Deletion_std_0                          -0.063842    -0.013274    0.138079
# d5Deletion_std_1                           0.027741     0.006471    0.069146
# frequencyCount (%)_max_0                  11.360391     0.209874   -1.018587
# frequencyCount (%)_max_1                   6.954274    -1.159714   -2.028672
# ...                                             ...          ...         ...
# Lungcancer_rel_cum_freq(perc)             -0.123813     0.396337   -0.090990
# Lupus_rel_cum_freq(perc)                  -0.086107    -0.092460    0.472601
# M.tuberculosis_rel_cum_freq(perc)          0.434261    -0.493660   -0.451712
# M.tuberculosis_rel_seq_count               0.205603    -0.448832   -0.450138
# Melanoma_rel_cum_freq(perc)               -0.290225    -1.173949    0.086640
# Melanoma_rel_seq_count                     0.145774    -1.129295    0.359518
# Multiplesclerosis_rel_cum_freq(perc)       0.125341     0.130997   -0.413961
# Multiplesclerosis_rel_seq_count            0.218639     0.400275   -0.466202
# Plasmodiumberghei_rel_cum_freq(perc)      -0.105193    -0.093855    0.498726
# RSV_rel_cum_freq(perc)                    -0.130530    -0.131078   -0.131929
# RheumatoidArthritis_rel_cum_freq(perc)    -0.646611     0.312021   -0.214722
# RheumatoidArthritis_rel_seq_count         -0.599926     0.221957    0.054139
# SIV_rel_cum_freq(perc)                     0.255856    -0.249632    0.856633
# SIV_rel_seq_count                          0.344424    -0.338148    1.055626
# WestNilevirus_rel_cum_freq(perc)          -0.187516    -0.178352    0.410847
# WestNilevirus_rel_seq_count               -0.231729    -0.226811    0.500265
# YellowFeverVirus_rel_cum_freq(perc)        2.814739    -1.394137    1.660041
# YellowFeverVirus_rel_seq_count             2.544991    -1.001241    1.601120
# totalAnnotateSeqs                        -38.389720   -60.042489  -18.280128
# totalAnnotatefreqs                        -0.634352    -0.174030   -0.407299
# PC1                                       -0.000798    -0.009116    0.000651
# PC2                                        0.027224     0.000784   -0.037080
# PC3                                        0.013302     0.031724   -0.044365
# PC4                                        0.017874     0.016982    0.034981
# PC5                                        0.063813     0.022296    0.060942
# PC6                                       -0.035486     0.020148   -0.046862
# PC7                                        0.010439     0.021353   -0.025977
# PC8                                       -0.024169     0.000711   -0.017544
# PC9                                       -0.010629    -0.002537    0.059365
# PC10                                      -0.043644     0.008293    0.032041
#
#                                               BD845
# AA count_0                               -14.096430
# AA count_1                              2013.417515
# NT count_0                              -322.135478
# NT count_1                              1813.931632
# berger_aa_0                                0.072180
# berger_aa_1                                0.017366
# berger_nt_0                                0.022499
# berger_nt_1                                0.017771
# cdr3Length_max_0                           2.773855
# cdr3Length_max_1                          -6.366037
# cdr3Length_mean_0                         -0.464890
# cdr3Length_mean_1                         -0.407256
# cdr3Length_std_0                          -0.055303
# cdr3Length_std_1                          -0.072425
# count (templates)_max_0                   75.135679
# count (templates)_max_1                  554.894466
# count (templates)_mean_0                   0.188198
# count (templates)_mean_1                   0.196890
# count (templates)_std_0                    1.669064
# count (templates)_std_1                    4.438527
# d3Deletion_mean_0                          0.089521
# d3Deletion_mean_1                          0.046334
# d3Deletion_std_0                           0.030007
# d3Deletion_std_1                           0.012588
# d5Deletion_mean_0                         -0.011708
# d5Deletion_mean_1                          0.025802
# d5Deletion_std_0                          -0.026400
# d5Deletion_std_1                           0.000199
# frequencyCount (%)_max_0                   0.193637
# frequencyCount (%)_max_1                   1.586508
# ...                                             ...
# Lungcancer_rel_cum_freq(perc)              0.144330
# Lupus_rel_cum_freq(perc)                   0.188435
# M.tuberculosis_rel_cum_freq(perc)         -0.529617
# M.tuberculosis_rel_seq_count              -0.447712
# Melanoma_rel_cum_freq(perc)               -0.996412
# Melanoma_rel_seq_count                    -0.737339
# Multiplesclerosis_rel_cum_freq(perc)       0.200812
# Multiplesclerosis_rel_seq_count            0.003902
# Plasmodiumberghei_rel_cum_freq(perc)      -0.108972
# RSV_rel_cum_freq(perc)                    -0.130348
# RheumatoidArthritis_rel_cum_freq(perc)    -0.355528
# RheumatoidArthritis_rel_seq_count         -0.156618
# SIV_rel_cum_freq(perc)                     0.060184
# SIV_rel_seq_count                          0.135270
# WestNilevirus_rel_cum_freq(perc)           0.081854
# WestNilevirus_rel_seq_count                0.201414
# YellowFeverVirus_rel_cum_freq(perc)       -1.629346
# YellowFeverVirus_rel_seq_count            -1.375290
# totalAnnotateSeqs                         34.161203
# totalAnnotatefreqs                        -0.239143
# PC1                                        0.006327
# PC2                                        0.026422
# PC3                                       -0.011807
# PC4                                       -0.068914
# PC5                                        0.066658
# PC6                                       -0.032251
# PC7                                        0.099075
# PC8                                       -0.028707
# PC9                                       -0.070744
# PC10                                      -0.070219
#
# [147 rows x 530 columns]

# %%
f1='/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/Predictions/featureDFs/residuals_Age.dat'
residuals.T.to_pickle(f1)

# %% [markdown]
# #### compare noam's resdiual's to mine:

# %%
# get dfs:
#phen:
f1='/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/PNP530Cardio126Combined/Phenotypes/\
PNP530Cardio126_AllInfo_withDummies.xlsx'
phenDF=pd.read_excel(f1).set_index('BD').loc[PNP530,:]
phenDF=phenDF['Age']

#features:
folder='/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/Predictions/featureDFs/'
X_corr_file='allTCRfeatures_percShared10__withRels_noT_AgeCorr.dat'
X_corr=pd.read_pickle(folder+X_corr_file).loc[PNP530,:]
# X_corr=X_corr.loc[PNP530,:]

X_file='allTCRfeatures_percShared10__withRels_noT.dat'
X=pd.read_pickle(folder+X_file).loc[PNP530,:]

# %%
col='simpson_nt_1'
data1=phenDF.loc[X.index]
data1name='Age'

fig,axes=plt.subplots(nrows=2,ncols=3,figsize=(12,8))
plt.suptitle(col,fontsize='xx-large')

for n in range(6):
    print n
    ax=axes.flatten()[n]
    if n%3==0:
        data2name=col
        data2=X[data2name]
        print len(data2)
        title='Not corrected'
       
        
    elif n%3==1:
        data2name=col+'_AgeCorrRes'
        data2=X_corr[data2name]
        print len(data2)
        title='Corrected'
      
    elif n%3==2:
        data2name=col
        data2=residuals.T[data2name]
        print len(data2)
        title='Corrected-Noam'
    
    if n<3:
        corrType='pearson'
    else:
        corrType='spearman'
        title='' 
        
    ax, nsamples,r,p,text=plot_corr(data1,data2,data1name,data2name,ax,title,corrType=corrType)
    ax.set_ylabel('')
    if n<3:
        ax.set_xlabel('')
        
plt.show()
# Out:
# 0
# 530
# 1
# 530
# 2
# 530
# 3
# 530
# 4
# 530
# 5
# 530

# %%
col='top10clonal_aa_1'
data1=phenDF.loc[X.index]
data1name='Age'

fig,axes=plt.subplots(nrows=2,ncols=3,figsize=(12,8))
plt.suptitle(col,fontsize='xx-large')

for n in range(6):
    print n
    ax=axes.flatten()[n]
    if n%3==0:
        data2name=col
        data2=X[data2name]
        print len(data2)
        title='Not corrected'
       
        
    elif n%3==1:
        data2name=col+'_AgeCorrRes'
        data2=X_corr[data2name]
        print len(data2)
        title='Corrected'
      
    elif n%3==2:
        data2name=col
        data2=residuals.T[data2name]
        print len(data2)
        title='Corrected-Noam'
    
    if n<3:
        corrType='pearson'
    else:
        corrType='spearman'
        title='' 
        
    ax, nsamples,r,p,text=plot_corr(data1,data2,data1name,data2name,ax,title,corrType=corrType)
    ax.set_ylabel('')
    if n<3:
        ax.set_xlabel('')
        
plt.show()
# Out:
# 0
# 530
# 1
# 530
# 2
# 530
# 3
# 530
# 4
# 530
# 5
# 530

# %%
col='HSV_rel_cum_freq(perc)'
data1=phenDF.loc[X.index]
data1name='Age'

fig,axes=plt.subplots(nrows=2,ncols=3,figsize=(12,8))
plt.suptitle(col,fontsize='xx-large')

for n in range(6):
    print n
    ax=axes.flatten()[n]
    if n%3==0:
        data2name=col
        data2=X[data2name]
        print len(data2)
        title='Not corrected'
       
        
    elif n%3==1:
        try:
            data2name=col+'_AgeCorrRes'
            data2=X_corr[data2name]
            print len(data2)
            title='Corrected'
        except:
            print 'no corrected column'
      
    elif n%3==2:
        data2name=col
        data2=residuals.T[data2name]
        print len(data2)
        title='Corrected-Noam'
    
    if n<3:
        corrType='pearson'
    else:
        corrType='spearman'
        title='' 
        
    ax, nsamples,r,p,text=plot_corr(data1,data2,data1name,data2name,ax,title,corrType=corrType,alpha=0.5)
    ax.set_ylabel('')
    if n<3:
        ax.set_xlabel('')
        
plt.show()
# Out:
# 0
# 530
# 1
# no corrected column
# 2
# 530
# 3
# 530
# 4
# no corrected column
# 5
# 530

# %% [markdown]
# # predicting age using different X matrices:

# %% [markdown]
# matrices used:
# 1. all seqs present in >10% samples
# 2. all seqs present in >10% samples+repertoire and annotation features
# 3. repertoire and annotation features
# 4. baseline - WBC and nTemplates only
# 5. control - repertoire and annotation features corrected for age
# 6. control - repertoire and annotation features corrected for age,gender and eGFR

# %% [markdown]
# ## get r and p values from each X:

# %%
result_folder='%s/TCR_real_data/predictions2/PNP530_majorPhenotypes' %MyPath
dirs=os.listdir(result_folder)
dirs
# Out:
# ['lin_cont_gridSearch_25_byRepFeatRelsSmall_AgeCorr',
#  'XGB_randomSearch_25_byVDJonly_ageCorr',
#  'lin_cont_randomSearch_25_byVDJ',
#  'XGB_randomSearch_25_byVDJ',
#  'oldPredictionTrial',
#  'XGB_randomSearch_25_byseqs10only',
#  'XGB_randomSearch_25_byRepFeatRelsSmall',
#  'XGB_randomSearch_25_byAgeResiduals',
#  'lin_cont_gridSearch_25_byRepFeatRelsSmall',
#  'lin_cont_gridSearch_25_byRepFeatRelsSmall_GenderCorr',
#  'XGB_randomSearch_25_byRepFeatRelsSeqs',
#  'XGB_randomSearch_25_byRepFeatRelsCorrected',
#  'XGB_randomSearch_25_byWBCnTemplates',
#  'XGB_randomSearch_25_byRepFeatRels',
#  'XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr',
#  'XGB_randomSearch_25_byRepFeatRelsAgeCorrected',
#  'XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr',
#  'XGB_randomSearch_25_byVDJ_ageCorr',
#  'LGBM_randomSearch_20_byVDJ_ageCorr']

# %%
dirs=['XGB_randomSearch_25_byRepFeatRelsSmall','XGB_randomSearch_25_byAgeResiduals',
      'XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr','XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr',
      'XGB_randomSearch_25_byVDJ', 'XGB_randomSearch_25_byVDJ_ageCorr',
      'XGB_randomSearch_25_byseqs10only','XGB_randomSearch_25_byWBCnTemplates']
# phen_list=[('Age',['Coefficient_of_determination','pearson_p','pearson_r','spearman_p','spearman_r']),('Gender_Male',['prevalence','AUC','Precision_Recall'])]
phen_list=[('Age',['Coefficient_of_determination','pearson_p','pearson_r','spearman_p','spearman_r'])]
for item in phen_list:
    phen=item[0]
    colList=item[1]
    print '**********************'
    print '*  '+phen
    print '**********************'
    print ''

    phen_df_list=[]
    for d in dirs:
        print '*******'+d+'*******'
        print ''
        print '--------'
        print 'PERFORMANCE'
        print '--------'
        f1='%s/%s/results_df.pkl' %(result_folder,d)
        results_df=pd.read_pickle(f1)
        phen_result=pd.DataFrame(results_df.loc[phen,colList])
        phen_result=phen_result.rename(columns={phen:d}).T
        phen_df_list.append(phen_result)
        print phen_result

        print '--------'
        print 'SHAP_VALUES'
        print '--------'
        f2='%s/%s/shap_values.pkl' %(result_folder,d)
        shap_values=pd.read_pickle(f2)

        for k,v in shap_values.items():
            if k ==phen:
    #         print k
    #         print '------------------------'
                print v.abs().sum().sort_values(ascending=False).head(20)
                impFeatures=v.abs().sum().sort_values(ascending=False).head(20)
            
        if phen == 'Age':
            sorting='pearson_r'
        else:
            sorting='AUC'
        phen_result_sum=pd.concat(phen_df_list).sort_values(by=sorting,ascending=False)
        print phen_result_sum
# Out:
# **********************
# *  Age
# **********************
#
# *******XGB_randomSearch_25_byRepFeatRelsSmall*******
#
# --------
# PERFORMANCE
# --------
#                                        Coefficient_of_determination  \
# XGB_randomSearch_25_byRepFeatRelsSmall                     0.305796
#
#                                           pearson_p pearson_r   spearman_p  \
# XGB_randomSearch_25_byRepFeatRelsSmall  1.52042e-43  0.553018  3.17731e-42
#
#                                        spearman_r
# XGB_randomSearch_25_byRepFeatRelsSmall   0.545692
# --------
# SHAP_VALUES
# --------
# PC2                         2100.252704
# cdr3Length_std_1             350.039978
# top1000clonal_aa_1           315.755721
# jDeletion_mean_1             311.178757
# d3Deletion_mean_1            295.383730
# normSeqNums_per2000_NT_1     291.384995
# n2Insertion_std_1            270.513503
# PC1                          269.840390
# totalAnnotatefreqs           227.591533
# d3Deletion_std_0             220.384746
# PC3                          202.812147
# DENV_rel_seq_count           200.862304
# normSeqNums_per200_AA_1      199.228814
# EBV_rel_cum_freq(perc)       197.120284
# top1000clonal_nt_1           194.551231
# d3Deletion_std_1             188.491658
# shannon_aa_1                 167.716629
# DENV_rel_cum_freq(perc)      149.582714
# d5Deletion_std_1             138.920534
# shannon_aa_0                 138.534829
# dtype: float64
#                                        Coefficient_of_determination  \
# XGB_randomSearch_25_byRepFeatRelsSmall                     0.305796
#
#                                           pearson_p pearson_r   spearman_p  \
# XGB_randomSearch_25_byRepFeatRelsSmall  1.52042e-43  0.553018  3.17731e-42
#
#                                        spearman_r
# XGB_randomSearch_25_byRepFeatRelsSmall   0.545692
# *******XGB_randomSearch_25_byAgeResiduals*******
#
# --------
# PERFORMANCE
# --------
#                                    Coefficient_of_determination pearson_p  \
# XGB_randomSearch_25_byAgeResiduals                     0.995744         0
#
#                                    pearson_r spearman_p spearman_r
# XGB_randomSearch_25_byAgeResiduals  0.997926          0   0.998261
# --------
# SHAP_VALUES
# --------
# GraftVsHostDisease_rel_cum_freq(perc)                3285.338801
# HSV_rel_cum_freq(perc)                               1571.142491
# Leukemia_rel_cum_freq(perc)                           821.922238
# Lungcancer_rel_cum_freq(perc)                         348.244816
# Plasmodiumberghei_rel_cum_freq(perc)                   84.754019
# CalcifiedAorticStenosisdisease_rel_cum_freq(perc)      84.662688
# RSV_rel_cum_freq(perc)                                 72.422514
# Lupus_rel_cum_freq(perc)                               45.296487
# simpson_aa_1                                           10.051862
# WestNilevirus_rel_cum_freq(perc)                        9.112865
# simpson_nt_0                                            9.044632
# simpson_aa_0                                            7.529499
# HTLV_rel_seq_count                                      6.233502
# SIV_rel_cum_freq(perc)                                  5.521946
# BreastCancer_rel_seq_count                              5.421134
# BreastCancer_rel_cum_freq(perc)                         4.796460
# jDeletion_max_0                                         3.225249
# max_nt_per_aa_0                                         2.955091
# normSeqNums_per200_AA_0                                 2.896150
# vDeletion_max_0                                         2.371144
# dtype: float64
#                                        Coefficient_of_determination  \
# XGB_randomSearch_25_byAgeResiduals                         0.995744
# XGB_randomSearch_25_byRepFeatRelsSmall                     0.305796
#
#                                           pearson_p pearson_r   spearman_p  \
# XGB_randomSearch_25_byAgeResiduals                0  0.997926            0
# XGB_randomSearch_25_byRepFeatRelsSmall  1.52042e-43  0.553018  3.17731e-42
#
#                                        spearman_r
# XGB_randomSearch_25_byAgeResiduals       0.998261
# XGB_randomSearch_25_byRepFeatRelsSmall   0.545692
# *******XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr*******
#
# --------
# PERFORMANCE
# --------
#                                                   Coefficient_of_determination  \
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr                     0.296529
#
#                                                     pearson_p pearson_r  \
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr  4.1881e-42  0.545017
#
#                                                     spearman_p spearman_r
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr  1.21625e-42   0.548026
# --------
# SHAP_VALUES
# --------
# PC2_Gender_MaleCorrRes                         1884.867741
# cdr3Length_std_1_Gender_MaleCorrRes             326.730261
# top1000clonal_aa_1_Gender_MaleCorrRes           295.690823
# jDeletion_mean_1                                283.347849
# top1000clonal_nt_1_Gender_MaleCorrRes           263.341468
# shannon_aa_1_Gender_MaleCorrRes                 260.834963
# PC3                                             226.650353
# d3Deletion_mean_1                               221.244104
# n2Insertion_std_1                               206.842724
# d3Deletion_std_0                                202.903544
# DENV_rel_seq_count                              202.568466
# totalAnnotatefreqs                              188.779416
# d3Deletion_std_1                                178.569192
# DENV_rel_cum_freq(perc)                         177.745952
# totalAnnotateSeqs_Gender_MaleCorrRes            174.861840
# n1Insertion_std_1_Gender_MaleCorrRes            167.769386
# normSeqNums_per2000_NT_1_Gender_MaleCorrRes     164.397910
# simpson_nt_0_Gender_MaleCorrRes                 154.957951
# PC1                                             154.190146
# EBV_rel_cum_freq(perc)                          146.926833
# dtype: float64
#                                                   Coefficient_of_determination  \
# XGB_randomSearch_25_byAgeResiduals                                    0.995744
# XGB_randomSearch_25_byRepFeatRelsSmall                                0.305796
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr                     0.296529
#
#                                                      pearson_p pearson_r  \
# XGB_randomSearch_25_byAgeResiduals                           0  0.997926
# XGB_randomSearch_25_byRepFeatRelsSmall             1.52042e-43  0.553018
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr   4.1881e-42  0.545017
#
#                                                     spearman_p spearman_r
# XGB_randomSearch_25_byAgeResiduals                           0   0.998261
# XGB_randomSearch_25_byRepFeatRelsSmall             3.17731e-42   0.545692
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr  1.21625e-42   0.548026
# *******XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr*******
#
# --------
# PERFORMANCE
# --------
#                                                Coefficient_of_determination  \
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr                     0.721941
#
#                                                    pearson_p pearson_r  \
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr  4.60082e-150  0.852559
#
#                                                   spearman_p spearman_r
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr  2.32036e-154   0.858461
# --------
# SHAP_VALUES
# --------
# simpson_nt_1_AgeCorrRes                2340.881761
# simpson_aa_1_AgeCorrRes                1446.643278
# simpson_nt_0                            997.629093
# frequencyCount (%)_std_0_AgeCorrRes     634.677819
# frequencyCount (%)_max_1_AgeCorrRes     458.191049
# totalAnnotatefreqs                      438.884409
# normSeqNums_per200_AA_1_AgeCorrRes      419.470450
# simpson_aa_0                            355.311955
# frequencyCount (%)_std_1_AgeCorrRes     321.044845
# frequencyCount (%)_max_0                316.201211
# top10clonal_aa_1_AgeCorrRes             311.825559
# berger_nt_0_AgeCorrRes                  280.068474
# top10clonal_nt_1_AgeCorrRes             218.335967
# cdr3Length_max_1_AgeCorrRes             198.212294
# normSeqNums_per200_AA_0_AgeCorrRes      196.066243
# frequencyCount (%)_mean_0               137.295868
# normSeqNums_per2000_NT_1_AgeCorrRes     134.937477
# count (templates)_std_0                 127.828902
# count (templates)_mean_1_AgeCorrRes     120.500495
# PC2_AgeCorrRes                          101.651967
# dtype: float64
#                                                   Coefficient_of_determination  \
# XGB_randomSearch_25_byAgeResiduals                                    0.995744
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr                        0.721941
# XGB_randomSearch_25_byRepFeatRelsSmall                                0.305796
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr                     0.296529
#
#                                                       pearson_p pearson_r  \
# XGB_randomSearch_25_byAgeResiduals                            0  0.997926
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr     4.60082e-150  0.852559
# XGB_randomSearch_25_byRepFeatRelsSmall              1.52042e-43  0.553018
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr    4.1881e-42  0.545017
#
#                                                      spearman_p spearman_r
# XGB_randomSearch_25_byAgeResiduals                            0   0.998261
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr     2.32036e-154   0.858461
# XGB_randomSearch_25_byRepFeatRelsSmall              3.17731e-42   0.545692
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr   1.21625e-42   0.548026
# *******XGB_randomSearch_25_byVDJ*******
#
# --------
# PERFORMANCE
# --------
#                           Coefficient_of_determination    pearson_p pearson_r  \
# XGB_randomSearch_25_byVDJ                     0.344894  1.71133e-50  0.588831
#
#                             spearman_p spearman_r
# XGB_randomSearch_25_byVDJ  1.27839e-45   0.564181
# --------
# SHAP_VALUES
# --------
# V06-04_1        1854.774971
# V05_1            462.105748
# V25_J02_1        427.123452
# V13-01_1         373.589864
# V19-01_1         368.954268
# V05-01_1         314.775764
# V18_J02_1        275.925598
# V27-01_1         272.018582
# V07-09_1         258.055013
# V02_J02_0        253.294241
# V05-05_1         252.618110
# V25_1            212.832319
# D01_J02-04_0     183.694499
# V05_J02_1        168.946608
# V13_J02_1        168.148675
# V05-08_1         165.160187
# D01_J01-05_1     135.295944
# V13_J02_0        118.116085
# J02-05_1         115.407927
# D02_J02-02_0     115.002347
# dtype: float64
#                                                   Coefficient_of_determination  \
# XGB_randomSearch_25_byAgeResiduals                                    0.995744
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr                        0.721941
# XGB_randomSearch_25_byVDJ                                             0.344894
# XGB_randomSearch_25_byRepFeatRelsSmall                                0.305796
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr                     0.296529
#
#                                                       pearson_p pearson_r  \
# XGB_randomSearch_25_byAgeResiduals                            0  0.997926
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr     4.60082e-150  0.852559
# XGB_randomSearch_25_byVDJ                           1.71133e-50  0.588831
# XGB_randomSearch_25_byRepFeatRelsSmall              1.52042e-43  0.553018
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr    4.1881e-42  0.545017
#
#                                                      spearman_p spearman_r
# XGB_randomSearch_25_byAgeResiduals                            0   0.998261
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr     2.32036e-154   0.858461
# XGB_randomSearch_25_byVDJ                           1.27839e-45   0.564181
# XGB_randomSearch_25_byRepFeatRelsSmall              3.17731e-42   0.545692
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr   1.21625e-42   0.548026
# *******XGB_randomSearch_25_byVDJ_ageCorr*******
#
# --------
# PERFORMANCE
# --------
#                                   Coefficient_of_determination    pearson_p  \
# XGB_randomSearch_25_byVDJ_ageCorr                     0.126048  3.65054e-17
#
#                                   pearson_r   spearman_p spearman_r
# XGB_randomSearch_25_byVDJ_ageCorr  0.355714  1.38968e-16   0.349471
# --------
# SHAP_VALUES
# --------
# V06-04_1_AgeCorrRes     573.154133
# V27_J01_1               459.615253
# V04-03_1                351.412375
# V07-09_1                291.393851
# V25_J02_1_AgeCorrRes    280.754493
# V06-05_1                275.713095
# V12_J02_0               257.945969
# V04_J02_1_AgeCorrRes    253.055243
# D01_J02-07_1            249.475220
# V20-01_0                221.616368
# D02_J02-02_0            208.619717
# V05-05_1_AgeCorrRes     206.577583
# V10_J01_1               197.141626
# V25_J02_0               186.277843
# D02_J02-06_1            182.674187
# J02-07_1_AgeCorrRes     176.250212
# V07-03_1                171.965455
# D01_J01-05_1            171.102498
# V13-01_1_AgeCorrRes     168.110474
# V11-01_1                165.800523
# dtype: float64
#                                                   Coefficient_of_determination  \
# XGB_randomSearch_25_byAgeResiduals                                    0.995744
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr                        0.721941
# XGB_randomSearch_25_byVDJ                                             0.344894
# XGB_randomSearch_25_byRepFeatRelsSmall                                0.305796
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr                     0.296529
# XGB_randomSearch_25_byVDJ_ageCorr                                     0.126048
#
#                                                       pearson_p pearson_r  \
# XGB_randomSearch_25_byAgeResiduals                            0  0.997926
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr     4.60082e-150  0.852559
# XGB_randomSearch_25_byVDJ                           1.71133e-50  0.588831
# XGB_randomSearch_25_byRepFeatRelsSmall              1.52042e-43  0.553018
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr    4.1881e-42  0.545017
# XGB_randomSearch_25_byVDJ_ageCorr                   3.65054e-17  0.355714
#
#                                                      spearman_p spearman_r
# XGB_randomSearch_25_byAgeResiduals                            0   0.998261
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr     2.32036e-154   0.858461
# XGB_randomSearch_25_byVDJ                           1.27839e-45   0.564181
# XGB_randomSearch_25_byRepFeatRelsSmall              3.17731e-42   0.545692
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr   1.21625e-42   0.548026
# XGB_randomSearch_25_byVDJ_ageCorr                   1.38968e-16   0.349471
# *******XGB_randomSearch_25_byseqs10only*******
#
# --------
# PERFORMANCE
# --------
#                                  Coefficient_of_determination   pearson_p  \
# XGB_randomSearch_25_byseqs10only                      0.23308  3.7511e-32
#
#                                  pearson_r   spearman_p spearman_r
# XGB_randomSearch_25_byseqs10only  0.482977  1.09673e-29   0.465414
# --------
# SHAP_VALUES
# --------
# CASSGTSGSTDTQYF    467.242726
# CASSELAGGTDTQYF    399.454629
# CASSDSSGSTDTQYF    394.078879
# CASSDSSGANVLTF     260.300177
# CASSDSSGGYNEQFF    224.053316
# CASSDSSGGANEQFF    210.778208
# CASSDSDTGELFF      205.467621
# CASSDSNTGELFF      170.748226
# CASSRDRGETQYF      168.081555
# CASSDGGATDTQYF     161.090447
# CASSDSSGSYNEQFF    150.471735
# CASSDGSTDTQYF      149.292110
# CASSLGGAGANVLTF    138.175347
# CASSDSSTDTQYF      119.582944
# CASSLSGSYEQYF      117.577830
# CASSEAGGSYNEQFF    114.558575
# CASSDRDTGELFF      112.059961
# CASSYSSGANVLTF     110.417629
# CASSFRETQYF        108.071195
# CASSFTGNTEAFF      103.973198
# dtype: float64
#                                                   Coefficient_of_determination  \
# XGB_randomSearch_25_byAgeResiduals                                    0.995744
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr                        0.721941
# XGB_randomSearch_25_byVDJ                                             0.344894
# XGB_randomSearch_25_byRepFeatRelsSmall                                0.305796
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr                     0.296529
# XGB_randomSearch_25_byseqs10only                                       0.23308
# XGB_randomSearch_25_byVDJ_ageCorr                                     0.126048
#
#                                                       pearson_p pearson_r  \
# XGB_randomSearch_25_byAgeResiduals                            0  0.997926
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr     4.60082e-150  0.852559
# XGB_randomSearch_25_byVDJ                           1.71133e-50  0.588831
# XGB_randomSearch_25_byRepFeatRelsSmall              1.52042e-43  0.553018
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr    4.1881e-42  0.545017
# XGB_randomSearch_25_byseqs10only                     3.7511e-32  0.482977
# XGB_randomSearch_25_byVDJ_ageCorr                   3.65054e-17  0.355714
#
#                                                      spearman_p spearman_r
# XGB_randomSearch_25_byAgeResiduals                            0   0.998261
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr     2.32036e-154   0.858461
# XGB_randomSearch_25_byVDJ                           1.27839e-45   0.564181
# XGB_randomSearch_25_byRepFeatRelsSmall              3.17731e-42   0.545692
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr   1.21625e-42   0.548026
# XGB_randomSearch_25_byseqs10only                    1.09673e-29   0.465414
# XGB_randomSearch_25_byVDJ_ageCorr                   1.38968e-16   0.349471
# *******XGB_randomSearch_25_byWBCnTemplates*******
#
# --------
# PERFORMANCE
# --------
#                                     Coefficient_of_determination pearson_p  \
# XGB_randomSearch_25_byWBCnTemplates                   -0.0188756   0.36219
#
#                                      pearson_r spearman_p spearman_r
# XGB_randomSearch_25_byWBCnTemplates  0.0297056   0.323736  0.0321693
# --------
# SHAP_VALUES
# --------
# nTemplates    1143.543022
# WBC            760.484562
# dtype: float64
#                                                   Coefficient_of_determination  \
# XGB_randomSearch_25_byAgeResiduals                                    0.995744
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr                        0.721941
# XGB_randomSearch_25_byVDJ                                             0.344894
# XGB_randomSearch_25_byRepFeatRelsSmall                                0.305796
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr                     0.296529
# XGB_randomSearch_25_byseqs10only                                       0.23308
# XGB_randomSearch_25_byVDJ_ageCorr                                     0.126048
# XGB_randomSearch_25_byWBCnTemplates                                 -0.0188756
#
#                                                       pearson_p  pearson_r  \
# XGB_randomSearch_25_byAgeResiduals                            0   0.997926
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr     4.60082e-150   0.852559
# XGB_randomSearch_25_byVDJ                           1.71133e-50   0.588831
# XGB_randomSearch_25_byRepFeatRelsSmall              1.52042e-43   0.553018
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr    4.1881e-42   0.545017
# XGB_randomSearch_25_byseqs10only                     3.7511e-32   0.482977
# XGB_randomSearch_25_byVDJ_ageCorr                   3.65054e-17   0.355714
# XGB_randomSearch_25_byWBCnTemplates                     0.36219  0.0297056
#
#                                                      spearman_p spearman_r
# XGB_randomSearch_25_byAgeResiduals                            0   0.998261
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr     2.32036e-154   0.858461
# XGB_randomSearch_25_byVDJ                           1.27839e-45   0.564181
# XGB_randomSearch_25_byRepFeatRelsSmall              3.17731e-42   0.545692
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr   1.21625e-42   0.548026
# XGB_randomSearch_25_byseqs10only                    1.09673e-29   0.465414
# XGB_randomSearch_25_byVDJ_ageCorr                   1.38968e-16   0.349471
# XGB_randomSearch_25_byWBCnTemplates                    0.323736  0.0321693

# %%
phen_result_sum=pd.concat(phen_df_list).sort_values(by='pearson_r',ascending=False)
phen_result_sum
# Out:
#                                                   Coefficient_of_determination  \
# XGB_randomSearch_25_byAgeResiduals                                    0.995744
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr                        0.721941
# XGB_randomSearch_25_byVDJ                                             0.344894
# XGB_randomSearch_25_byRepFeatRelsSmall                                0.305796
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr                     0.296529
# XGB_randomSearch_25_byseqs10only                                       0.23308
# XGB_randomSearch_25_byVDJ_ageCorr                                     0.126048
# XGB_randomSearch_25_byWBCnTemplates                                 -0.0188756
#
#                                                       pearson_p  pearson_r  \
# XGB_randomSearch_25_byAgeResiduals                            0   0.997926
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr     4.60082e-150   0.852559
# XGB_randomSearch_25_byVDJ                           1.71133e-50   0.588831
# XGB_randomSearch_25_byRepFeatRelsSmall              1.52042e-43   0.553018
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr    4.1881e-42   0.545017
# XGB_randomSearch_25_byseqs10only                     3.7511e-32   0.482977
# XGB_randomSearch_25_byVDJ_ageCorr                   3.65054e-17   0.355714
# XGB_randomSearch_25_byWBCnTemplates                     0.36219  0.0297056
#
#                                                      spearman_p spearman_r
# XGB_randomSearch_25_byAgeResiduals                            0   0.998261
# XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr     2.32036e-154   0.858461
# XGB_randomSearch_25_byVDJ                           1.27839e-45   0.564181
# XGB_randomSearch_25_byRepFeatRelsSmall              3.17731e-42   0.545692
# XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr   1.21625e-42   0.548026
# XGB_randomSearch_25_byseqs10only                    1.09673e-29   0.465414
# XGB_randomSearch_25_byVDJ_ageCorr                   1.38968e-16   0.349471
# XGB_randomSearch_25_byWBCnTemplates                    0.323736  0.0321693

# %% [markdown]
# ## get selected params:

# %%
dirs=['XGB_randomSearch_25_byRepFeatRelsSmall','XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr','XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr',
     'XGB_randomSearch_25_byVDJ','XGB_randomSearch_25_byseqs10only','XGB_randomSearch_25_byWBCnTemplates']
phen_list=[('Age',['Coefficient_of_determination','pearson_p','pearson_r','spearman_p','spearman_r']),('Gender_Male',['prevalence','AUC','Precision_Recall'])]

for item in phen_list:
    phen=item[0]
    colList=item[1]
    print '**********************'
    print '*  '+phen
    print '**********************'
    print ''

    phen_df_list=[]
    for d in dirs:
        print '*******'+d+'*******'
        print ''
        print '--------'
        print 'selected prarams'
        print '--------'
        f1='%s/%s/selected_model_params.pkl' %(result_folder,d)
        selected_model_params=pd.read_pickle(f1)
        print selected_model_params['Age']
# Out:
# **********************
# *  Age
# **********************
#
# *******XGB_randomSearch_25_byRepFeatRelsSmall*******
#
# --------
# selected prarams
# --------
#     gamma  learning_rate  max_depth  n_estimators  reg_alpha  subsample
# 1       0          0.005          1          1400          1        0.5
# 2       0          0.005          3          1400          5        0.7
# 3       1          0.005          3          1400          0        0.7
# 4       1          0.005          3          1000         10        0.5
# 5       0          0.010          3           600          1        0.5
# 6      10          0.100          1           200          5        0.7
# 7       1          0.005          3          1400          1        0.5
# 8       1          0.050          3           200          1        0.5
# 9       1          0.010          1          1400         10        0.5
# 10      1          0.050          1           200         10        0.5
# *******XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr*******
#
# --------
# selected prarams
# --------
#     gamma  learning_rate  max_depth  n_estimators  reg_alpha  subsample
# 1       5          0.010          3          1000          1        0.5
# 2       5          0.005          1          1400          0        0.5
# 3       1          0.005          1          1000          0        0.5
# 4       0          0.010          1          1400          0        0.5
# 5       0          0.005          1          1400          0        0.5
# 6       5          0.005          1          1000          5        0.5
# 7      10          0.010          1          1000          0        0.5
# 8       1          0.010          1          1400          0        0.5
# 9       1          0.010          1          1400          1        0.5
# 10      1          0.010          3          1400         10        0.5
# *******XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr*******
#
# --------
# selected prarams
# --------
#     gamma  learning_rate  max_depth  n_estimators  reg_alpha  subsample
# 1      10           0.01          3          1400          0        0.7
# 2       1           0.01          3          1000          5        0.5
# 3      10           0.05          3          1400          5        0.5
# 4       1           0.10          3           600          0        0.7
# 5       0           0.01          5          1400          1        0.7
# 6       0           0.01          5          1400          0        0.7
# 7       1           0.01          3          1400          1        0.7
# 8       5           0.01          3          1400          5        0.7
# 9       1           0.01          3          1400          5        0.7
# 10      5           0.10          3           200          1        0.7
# *******XGB_randomSearch_25_byVDJ*******
#
# --------
# selected prarams
# --------
#     gamma  learning_rate  max_depth  n_estimators  reg_alpha  subsample
# 1       1          0.100          1           200          1        0.5
# 2      10          0.010          1          1400          5        0.5
# 3       5          0.010          1          1000         10        0.7
# 4       5          0.050          1           200         10        0.5
# 5      10          0.005          3          1400          5        0.5
# 6       0          0.100          1           200          5        0.7
# 7       0          0.005          3          1400          0        0.5
# 8       5          0.010          1          1000         10        0.5
# 9       5          0.010          1          1000          5        0.5
# 10      1          0.005          3          1400          5        0.5
# *******XGB_randomSearch_25_byseqs10only*******
#
# --------
# selected prarams
# --------
#     gamma  learning_rate  max_depth  n_estimators  reg_alpha  subsample
# 1      10          0.005          9          1000          1        0.5
# 2      10          0.005          7          1000          1        0.5
# 3       1          0.010          9          1000          1        0.5
# 4       1          0.005          9          1400          1        0.7
# 5       5          0.005          9          1000          0        0.5
# 6      10          0.010          7           600          0        0.5
# 7       5          0.010          5           600          1        0.7
# 8       5          0.010          7           600          1        0.7
# 9       5          0.005          5          1400          0        0.7
# 10     10          0.010          5           600          1        0.5
# *******XGB_randomSearch_25_byWBCnTemplates*******
#
# --------
# selected prarams
# --------
#     gamma  learning_rate  max_depth  n_estimators  reg_alpha  subsample
# 1       0          0.010          1           600          5        0.7
# 2       5          0.005          1          1000         10        0.7
# 3       5          0.010          1           600          0        0.7
# 4       1          0.005          3          1000          1        0.5
# 5       0          0.005          1          1000          5        0.5
# 6       1          0.005          1          1400         10        0.7
# 7       1          0.010          1          1000          0        0.7
# 8       5          0.005          1          1400          1        0.5
# 9       0          0.010          1          1400          5        0.5
# 10      5          0.005          1           600          0        0.7
# **********************
# *  Gender_Male
# **********************
#
# *******XGB_randomSearch_25_byRepFeatRelsSmall*******
#
# --------
# selected prarams
# --------
#     gamma  learning_rate  max_depth  n_estimators  reg_alpha  subsample
# 1       0          0.005          1          1400          1        0.5
# 2       0          0.005          3          1400          5        0.7
# 3       1          0.005          3          1400          0        0.7
# 4       1          0.005          3          1000         10        0.5
# 5       0          0.010          3           600          1        0.5
# 6      10          0.100          1           200          5        0.7
# 7       1          0.005          3          1400          1        0.5
# 8       1          0.050          3           200          1        0.5
# 9       1          0.010          1          1400         10        0.5
# 10      1          0.050          1           200         10        0.5
# *******XGB_randomSearch_25_byRepFeatRelsSmall_GenderCorr*******
#
# --------
# selected prarams
# --------
#     gamma  learning_rate  max_depth  n_estimators  reg_alpha  subsample
# 1       5          0.010          3          1000          1        0.5
# 2       5          0.005          1          1400          0        0.5
# 3       1          0.005          1          1000          0        0.5
# 4       0          0.010          1          1400          0        0.5
# 5       0          0.005          1          1400          0        0.5
# 6       5          0.005          1          1000          5        0.5
# 7      10          0.010          1          1000          0        0.5
# 8       1          0.010          1          1400          0        0.5
# 9       1          0.010          1          1400          1        0.5
# 10      1          0.010          3          1400         10        0.5
# *******XGB_randomSearch_25_byRepFeatRelsSmall_AgeCorr*******
#
# --------
# selected prarams
# --------
#     gamma  learning_rate  max_depth  n_estimators  reg_alpha  subsample
# 1      10           0.01          3          1400          0        0.7
# 2       1           0.01          3          1000          5        0.5
# 3      10           0.05          3          1400          5        0.5
# 4       1           0.10          3           600          0        0.7
# 5       0           0.01          5          1400          1        0.7
# 6       0           0.01          5          1400          0        0.7
# 7       1           0.01          3          1400          1        0.7
# 8       5           0.01          3          1400          5        0.7
# 9       1           0.01          3          1400          5        0.7
# 10      5           0.10          3           200          1        0.7
# *******XGB_randomSearch_25_byVDJ*******
#
# --------
# selected prarams
# --------
#     gamma  learning_rate  max_depth  n_estimators  reg_alpha  subsample
# 1       1          0.100          1           200          1        0.5
# 2      10          0.010          1          1400          5        0.5
# 3       5          0.010          1          1000         10        0.7
# 4       5          0.050          1           200         10        0.5
# 5      10          0.005          3          1400          5        0.5
# 6       0          0.100          1           200          5        0.7
# 7       0          0.005          3          1400          0        0.5
# 8       5          0.010          1          1000         10        0.5
# 9       5          0.010          1          1000          5        0.5
# 10      1          0.005          3          1400          5        0.5
# *******XGB_randomSearch_25_byseqs10only*******
#
# --------
# selected prarams
# --------
#     gamma  learning_rate  max_depth  n_estimators  reg_alpha  subsample
# 1      10          0.005          9          1000          1        0.5
# 2      10          0.005          7          1000          1        0.5
# 3       1          0.010          9          1000          1        0.5
# 4       1          0.005          9          1400          1        0.7
# 5       5          0.005          9          1000          0        0.5
# 6      10          0.010          7           600          0        0.5
# 7       5          0.010          5           600          1        0.7
# 8       5          0.010          7           600          1        0.7
# 9       5          0.005          5          1400          0        0.7
# 10     10          0.010          5           600          1        0.5
# *******XGB_randomSearch_25_byWBCnTemplates*******
#
# --------
# selected prarams
# --------
#     gamma  learning_rate  max_depth  n_estimators  reg_alpha  subsample
# 1       0          0.010          1           600          5        0.7
# 2       5          0.005          1          1000         10        0.7
# 3       5          0.010          1           600          0        0.7
# 4       1          0.005          3          1000          1        0.5
# 5       0          0.005          1          1000          5        0.5
# 6       1          0.005          1          1400         10        0.7
# 7       1          0.010          1          1000          0        0.7
# 8       5          0.005          1          1400          1        0.5
# 9       0          0.010          1          1400          5        0.5
# 10      5          0.005          1           600          0        0.7

# %% [markdown]
# # using more stringent cutoff for correcting features

# %% [markdown]
# ## correcting

# %%
# !python /home/sbenari/workspace/Microbiome/ShaniBA/TCR_feature_generation/FeatureCorrection_byLinReg.py \
/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/Predictions/featureDFs/allTCRfeatures_percShared10__withRels_noT.dat \
-path_to_phenotype_DF /net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/PNP530Cardio126Combined/Phenotypes/PNP530Cardio126_AllInfo_withDummies.xlsx \
-phen_list '["Age","Gender_Male","eGFR by CKD-EPI"]' -FDR 0.1
# Out:
# stop
# stop
# done1
# done
# done
# main
# ('Xfile: ', '/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/Predictions/featureDFs/allTCRfeatures_percShared10__withRels_noT.dat')
# ('Xdir: ', '/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_real_data/Predictions/featureDFs/')
# ('Xname: ', 'allTCRfeatures_percShared10__withRels_noT')
# X Index is already "bd" or no such column exist
# ('phenotypes to correct for are:', [u'Age', u'Gender_Male', u'eGFR by CKD-EPI'])
# correcting allTCRfeatures_percShared10__withRels_noT for Age
# (u'Age series type:', dtype('float64'))
# checking associations between Age and all TCR features:
# Traceback (most recent call last):
#   File "/home/sbenari/workspace/Microbiome/ShaniBA/TCR_feature_generation/FeatureCorrection_byLinReg.py", line 230, in <module>
#     main()
#   File "/home/sbenari/workspace/Microbiome/ShaniBA/TCR_feature_generation/FeatureCorrection_byLinReg.py", line 201, in main
#     featToCorrect=check_features_to_correct(X,Xname,phenDF,phen,sampleSubset,command_args)
#   File "/home/sbenari/workspace/Microbiome/ShaniBA/TCR_feature_generation/FeatureCorrection_byLinReg.py", line 52, in check_features_to_correct
#     print 'number of phenotype unique values is %s and therefore correlation test is used' %phenotypeDF[phen].nunique()
#   File "/usr/wisdom/python/lib/python2.7/site-packages/pandas/core/series.py", line 767, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/usr/wisdom/python/lib/python2.7/site-packages/pandas/core/indexes/base.py", line 3132, in get_value
#     raise e1
# KeyError: u'Age'

# %% [markdown]
# # use combined VDJ+rep features

# %% [markdown]
# regress for age using more stringent cut-off (q=0.01)

# %% [markdown]
# ## combine VDJ+rep features

# %% [markdown]
# ## regress using stringent cutoff for corrections

# %% [markdown]
# ## predict age (and gender) using the corrected and the non-corrected features
