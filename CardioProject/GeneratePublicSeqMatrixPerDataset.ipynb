# %% [markdown]
# # imports

# %% [markdown]
# the functions in this notebook are based on the notebook 'Public analysis- PNP cohort'

# %%
from os import listdir,mkdir,makedirs
from os.path import isfile, join, isdir,exists
import pandas as pd
import numpy as np
from scipy import stats
import re
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from myplots import roundup, rounddown, find_decimal_fold, percentile_cut_off, rarefaction_calc, rarefaction_plot,draw_correlation_scatter
from matplotlib.ticker import FormatStrFormatter
import cPickle as pickle
from Bio.SeqUtils import GC
import seaborn as sns
import random
from scipy.stats import pearsonr
from skbio.diversity.alpha import shannon, simpson, berger_parker_d

from pop_organize import get_sample_data, get_sample_with_dfs
from SufficientStatistics.SufficientStatistics import *
from MyFunctionsShani import *
import math
from myplots import roundup, rounddown, find_decimal_fold
from skbio.stats.distance import mantel
from scipy.spatial.distance import braycurtis, pdist
from GeneralFeaturePhenotypeInteractions.Feature_phenotype_functions import * 
from TCR_microbiome_interactions.TCR_microbiome_interactions_functions import *
from TCR_feature_generation.SubsamplingFunctions import *
from TCR_feature_generation.TCR_feature_generation_functions import *
from TCR_feature_generation.publicSeqAnalysis import *

MyPath='/net/mraid08/export/genie/Lab/Personal/ShaniBAF'
# Out:
# done1
# stop
# stop
# done1
# stop
# done
# done

# %%
import time
cdate=str(time.strftime("%d%m%Y"))
cdate
# Out:
# '24052018'

# %% [markdown]
# # generate sharing matrices for different datasets and minNshared:

# %% [markdown]
# the function gen_sharingMatrix_perDataset was copied to publicSeqAnalyis.py

# %%
# run for the full dataset, get statistics:


datasetName='PNP515'
dataset_folder='%s/TCR_real_data' %MyPath #change as necessary
minNsharedList=[2,50]

gen_sharingMatrix_perDataset(datasetName,dataset_folder,minNsharedList,extractUniqueAA=False,getSharingStatistics=True)

# %%
datasetName='PNP515_ss9000_rep1'
dataset_folder='%s/TCR_real_data/SubSampled9000 data' %MyPath #change as necessary
minNsharedList=[2,50]

gen_sharingMatrix_perDataset(datasetName,dataset_folder,minNsharedList,extractUniqueAA=False,getSharingStatistics=True)

# %%
datasetName='PNP515_ss9000_rep2'
dataset_folder='%s/TCR_real_data/SubSampled9000data_rep2' %MyPath #change as necessary
minNsharedList=[2,50]

gen_sharingMatrix_perDataset(datasetName,dataset_folder,minNsharedList,extractUniqueAA=False,getSharingStatistics=True)

# %%
datasetName='PNP515_ss12500_rep1'
dataset_folder='%s/TCR_real_data/SubSampled12500 data' %MyPath #change as necessary
minNsharedList=[2,50]

gen_sharingMatrix_perDataset(datasetName,dataset_folder,minNsharedList,extractUniqueAA=False,getSharingStatistics=True)

# %%
datasetName='PNP515_ss12500_rep2'
dataset_folder='%s/TCR_real_data/SubSampled12500data_rep2' %MyPath #change as necessary
minNsharedList=[2,50]

gen_sharingMatrix_perDataset(datasetName,dataset_folder,minNsharedList,extractUniqueAA=True,getSharingStatistics=True)

# %%
datasetName='PNP515_ss15000_rep1'
dataset_folder='%s/TCR_real_data/SubSampled15000data_rep1' %MyPath #change as necessary
minNsharedList=[2,50]

gen_sharingMatrix_perDataset(datasetName,dataset_folder,minNsharedList,extractUniqueAA=True,getSharingStatistics=True)

# %%
datasetName='PNP515_ss15000_rep2'
dataset_folder='%s/TCR_real_data/SubSampled15000data_rep2' %MyPath #change as necessary
minNsharedList=[2,50]

gen_sharingMatrix_perDataset(datasetName,dataset_folder,minNsharedList,extractUniqueAA=True,getSharingStatistics=True)

# %%
datasetName='PNP515_ss18000_rep1'
dataset_folder='%s/TCR_real_data/SubSampled18000 data' %MyPath #change as necessary
minNsharedList=[2,50]

gen_sharingMatrix_perDataset(datasetName,dataset_folder,minNsharedList,extractUniqueAA=True,getSharingStatistics=True)

# %%
datasetName='PNP515_ss18000_rep2'
dataset_folder='%s/TCR_real_data/SubSampled18000data_rep2' %MyPath #change as necessary
minNsharedList=[2,50]

gen_sharingMatrix_perDataset(datasetName,dataset_folder,minNsharedList,extractUniqueAA=True,getSharingStatistics=True)

# %%
# run for the full dataset, get statistics:


datasetName='PNP515'
dataset_folder='%s/TCR_real_data' %MyPath #change as necessary
minNsharedList=[10]

haringMatrix_RA=gen_sharingMatrix_perDataset(datasetName,dataset_folder,minNsharedList,extractUniqueAA=False,getSharingStatistics=True)

# %%
haringMatrix_RA.index[:50]

# %% [markdown]
# ## generate sharing matrix for productive sequences only

# %%
datasetName='PNP515_ss15000_rep2'
dataset_folder='%s/TCR_real_data/SubSampled15000data_rep2' %MyPath #change as necessary
minNsharedList=[2]

gen_sharingMatrix_perDataset(datasetName,dataset_folder,minNsharedList,extractUniqueAA=True,getSharingStatistics=True,onlyProductive=True)
# Out:
# number of samples in folder is 392
# extracting unique aa sequenecs from all samples...
# 0 BD889_15000
# 1 BD401_15000
# 2 BD586_1_15000
# 3 BD124_322939_2_15000
# 4 BD382_15000
# 5 BD549_15000
# 6 BD517_15000
# 7 BD904_15000
# 8 BD477_15000
# 9 BD657_1_15000
# 10 BD739_1_15000
# 11 BD888_15000
# 12 BD14_15000
# 13 BD865_15000
# 14 BD383_15000
# 15 BD596_1_15000
# 16 BD476_15000
# 17 BD428_15000
# 18 BD905_15000
# 19 BD563_15000
# 20 BD49_15000
# 21 BD185_15000
# 22 BD498_15000
# 23 BD810_15000
# 24 BD403_15000
# 25 BD677_1_15000
# 26 BD333_15000
# 27 BD158_322939_2_15000
# 28 BD906_15000
# 29 BD838_15000
# 30 BD137_322939_2_15000
# 31 BD79_322939_2_15000
# 32 BD16_15000
# 33 BD764_1_15000
# 34 BD605_1_15000
# 35 BD907_15000
# 36 BD474_15000
# 37 BD381_15000
# 38 BD867_15000
# 39 BD706_1_15000
# 40 BD668_1_15000
# 41 BD839_15000
# 42 BD900_15000
# 43 BD343_15000
# 44 BD600_15000
# 45 BD714_2_15000
# 46 BD153_322939_2_15000
# 47 BD11_15000
# 48 BD128_1rep_15000
# 49 BD565_15000
# ...

# %%
datasetName='PNP515_ss9000_rep2'
dataset_folder='%s/TCR_real_data/SubSampled9000data_rep2' %MyPath #change as necessary
minNsharedList=[2]

gen_sharingMatrix_perDataset(datasetName,dataset_folder,minNsharedList,extractUniqueAA=True,getSharingStatistics=True,onlyProductive=True)
# Out:
# number of samples in folder is 490
# extracting unique aa sequenecs from all samples...
# 0 BD906_9000
# 1 BD352_9000
# 2 BD465_9000
# 3 BD142_322939_2_9000
# 4 BD185_9000
# 5 BD909_9000
# 6 BD682_1_9000
# 7 BD23_9000
# 8 BD664_1_9000
# 9 BD835_9000
# 10 BD483_9000
# 11 BD694_1_9000
# 12 BD157_322939_2_9000
# 13 BD501_9000
# 14 BD862_9000
# 15 BD239_9000
# 16 BD449_2_9000
# 17 BD432_9000
# 18 BD884_9000
# 19 BD195_9000
# 20 BD579_1_9000
# 21 BD33_9000
# 22 BD919_9000
# 23 BD916_9000
# 24 BD791_9000
# 25 BD549_9000
# 26 BD149_322939_2_9000
# 27 BD546_9000
# 28 BD184_2_9000
# 29 BD57_322939_2_9000
# 30 BD701_1_9000
# 31 BD229_9000
# 32 BD717_1_9000
# 33 BD422_9000
# 34 BD894_9000
# 35 BD941_9000
# 36 BD764_1_9000
# 37 BD134_322939_2_9000
# 38 BD929_9000
# 39 BD789_1_9000
# 40 BD121_322939_2_9000
# 41 BD926_9000
# 42 BD372_9000
# 43 BD730_1_9000
# 44 BD412_9000
# 45 BD726_1_9000
# 46 BD842_9000
# 47 BD805_9000
# 48 BD566_9000
# 49 BD362_9000
# 50 BD936_9000
# 51 BD13_9000
# ...
