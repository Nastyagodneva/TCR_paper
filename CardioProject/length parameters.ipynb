# %%
from os import listdir
from os.path import isfile, join
# from Utils import Load, Write
import pandas as pd
import numpy as np
from scipy import stats
# import math
import re
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
# from matplotlib import cm
# import plotly.plotly as py
from myplots import roundup, rounddown, find_decimal_fold, percentile_cut_off, rarefaction_calc, rarefaction_plot
from matplotlib.ticker import FormatStrFormatter
import cPickle as pickle
from Bio.SeqUtils import GC
from pop_calcs import *
from pop_organize import *
from skbio.diversity.alpha import shannon, simpson, berger_parker_d

# %%
#########################
#    main function      #
#########################

##generate list of sample file names:
onlyfiles = [f for f in listdir("/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/CSVfiles") if isfile(join("/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/CSVfiles", f))]
onlyfiles = [datafile for datafile in onlyfiles if datafile.startswith ('HIP') and datafile.endswith('.csv')]
sample_names=[re.sub('.csv', '', datafile) for datafile in onlyfiles] ## generate list of 
                                                                      ## sample names out 
                                                                      ##of the sample file names
df_file_names,samples_with_df=get_sample_with_dfs() ## check which samples have df
generate_dfs=False ##False=load them from pickles, True=generate them. 

df_n=2 ## define number of dfs (prod, non-prod) *** check for update!***
# Out:
# getting list of samples that have dfs...
# finished getting list of samples that have dfs

# %%
##length functions: 


def mean_cdr3(df):
    mean_cdr3=np.mean(df['cdr3Length'])
    return mean_cdr3

def sv_cdr3(df):
    sv_cdr3=np.std(df['cdr3Length'])/np.mean(df['cdr3Length'])
    return sv_cdr3

def mean_vDeletion(df):
    mean_vDeletion=np.mean(df['vDeletion'])
    return mean_vDeletion

def sv_vDeletion(df):
    sv_vDeletion=np.std(df['vDeletion'])/np.mean(df['vDeletion'])
    return sv_vDeletion

def mean_n1Insertion(df):
    mean_n1Insertion=np.mean(df['n1Insertion'])
    return mean_n1Insertion

def sv_n1Insertion(df):
    sv_n1Insertion=np.std(df['n1Insertion'])/np.mean(df['n1Insertion'])
    return sv_n1Insertion

def mean_d5Deletion(df):
    mean_d5Deletion=np.mean(df['d5Deletion'])
    return mean_d5Deletion

def sv_d5Deletion(df):
    sv_d5Deletion=np.std(df['d5Deletion'])/np.mean(df['d5Deletion'])
    return sv_d5Deletion

def mean_d3Deletion(df):
    mean_d3Deletion=np.mean(df['d3Deletion'])
    return mean_d3Deletion

def sv_d3Deletion(df):
    sv_d3Deletion=np.std(df['d3Deletion'])/np.mean(df['d3Deletion'])
    return sv_d3Deletion

def mean_n2Insertion(df):
    mean_n2Insertion=np.mean(df['n2Insertion'])
    return mean_n2Insertion

def sv_n2Insertion(df):
    sv_n2Insertion=np.std(df['n2Insertion'])/np.mean(df['n2Insertion'])
    return sv_n2Insertion

def mean_jDeletion(df):
    mean_jDeletion=np.mean(df['jDeletion'])
    return mean_jDeletion

def sv_jDeletion(df):
    sv_jDeletion=np.std(df['jDeletion'])/np.mean(df['jDeletion'])
    return sv_jDeletion

# %%
length_func_list=[mean_cdr3, sv_cdr3, mean_vDeletion, sv_vDeletion, mean_n1Insertion, sv_n1Insertion, mean_d5Deletion, sv_d5Deletion, 
                  mean_d3Deletion, sv_d3Deletion, mean_n2Insertion, sv_n2Insertion, mean_jDeletion, sv_jDeletion]

# %%
def generate_res_DF(sample_names, function_list, df_n):
    print 'generating result dataframe...'
    result_df=pd.DataFrame({'Sample': sample_names})
    result_df=result_df.set_index('Sample')
    function_names=[f.__name__ for f in function_list]
    for function in function_names:
        for i in range(df_n):
            col_title=function+'_df_%s' %str(i)
            result_df[col_title]=np.NaN
    print 'finished generating result dataframe'
    return result_df

# %%
length_res_df=generate_res_DF(samples_with_df, length_func_list, df_n)
# Out:
# generating result dataframe...
# finished generating result dataframe

# %%
def get_sample_data(sample_name, generate_dfs): 
## this function generates dfs (general, only productive and only non productive) for each sample, and save
## as pickles. alternatively, it loads these dfs from pickles. 
    
    print 'getting sample data...'
    
    if generate_dfs:
        sample_df=pd.read_table("/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/%s.tsv" %sample_name)  
        sample_df_prod = sample_df[sample_df['sequenceStatus'] == 'In']
        sample_df_non_prod = sample_df[sample_df['sequenceStatus'] != 'In']
        
        pickle.dump(sample_df, open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/Pickles/sample_df_%s' %sample_name, "wb"))
        pickle.dump(sample_df_prod, open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/Pickles/sample_df_prod_%s' %sample_name, "wb"))
        pickle.dump(sample_df_non_prod, open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/Pickles/sample_df_non_prod_%s' %sample_name, "wb"))
    else:
        sample_df= pickle.load( open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/Pickles/sample_df_%s' %sample_name,"rb" ))
        sample_df_prod= pickle.load( open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/Pickles/sample_df_prod_%s' %sample_name,"rb" ))
        sample_df_non_prod= pickle.load( open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/Pickles/sample_df_non_prod_%s' %sample_name,"rb" ))
    
    print 'finished getting sample data'
    return sample_df, sample_df_prod, sample_df_non_prod

#_________________________________________________________________

# %%
def calculate_res_df(result_df,function_list, sample_name, sample_df_prod, sample_df_non_prod, **kwargs):
    ind=0
    df_list=[sample_df_prod, sample_df_non_prod] ## df list is generated here and doesnt come 
                                                 ## as input as it contains the specfic dfs
                                                 ##for each sample   
    
    for j, func in enumerate(function_list):
        for i, df in enumerate(df_list):
            result=func(df, **kwargs)
            result_df.loc[sample_name, result_df.columns[ind]]=result
            ind+=1
    return result_df

# %%
n_samples=573

# %%
n=1
for d in range(len(samples_with_df[:n_samples])): ##***change here for more samples!***
    sample_name=samples_with_df[d]
    print n
    print sample_name
## extract prod and non-prod dfs: 
    sample_df, sample_df_prod, sample_df_non_prod=get_sample_data(sample_name, generate_dfs)
#    percent_prod=perc_prod(sample_df)
#    perProd_res_df.loc[sample_name, 'perc_prod_df_0']=percent_prod
#    general_res_df=calculate_res_df(general_res_df,general_function_list, sample_name, sample_df_prod, sample_df_non_prod) 
#    clonality_res_df=calculate_res_df(clonality_res_df,clonality_func_list, sample_name, sample_df_prod, sample_df_non_prod)
#    diversity_res_df=calculate_res_df(diversity_res_df,diversity_func_list, sample_name, sample_df_prod, sample_df_non_prod)
    length_res_df=calculate_res_df(length_res_df,length_func_list, sample_name, sample_df_prod, sample_df_non_prod)
    n=n+1
#with open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/Pickles/general_res_df_%s_samples' %n_samples, "wb") as f1:
#    pickle.dump(general_res_df, f1)
#with open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/Pickles/perProd_res_df_%s_samples' %n_samples, "wb") as f2:
#    pickle.dump(perProd_res_df, f2)
#with open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/Pickles/clonality_res_df_%s_samples' %n_samples, "wb") as f3:
#    pickle.dump(clonality_res_df, f3)
#with open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/Pickles/diversity_res_df_%s_samples' %n_samples, "wb") as f4:
#    pickle.dump(diversity_res_df, f4)
with open('/net/mraid08/export/genie/Lab/Personal/ShaniBAF/TCR_demo_data/Pickles/length_res_df_%s_samples' %n_samples, "wb") as f5:
    pickle.dump(length_res_df, f5)
# Out:
# 1
# HIP11513
# getting sample data...
# finished getting sample data
# 2
# HIP08200
# getting sample data...
# finished getting sample data
# 3
# HIP00769
# getting sample data...
# finished getting sample data
# 4
# HIP09122
# getting sample data...
# finished getting sample data
# 5
# HIP12091
# getting sample data...
# finished getting sample data
# 6
# HIP13710
# getting sample data...
# finished getting sample data
# 7
# HIP13789
# getting sample data...
# finished getting sample data
# 8
# HIP02947
# getting sample data...
# finished getting sample data
# 9
# HIP03732
# getting sample data...
# finished getting sample data
# 10
# HIP14143
# getting sample data...
# finished getting sample data
# 11
# HIP14134
# getting sample data...
# finished getting sample data
# 12
# HIP14039
# getting sample data...
# finished getting sample data
# 13
# HIP13933
# getting sample data...
# finished getting sample data
# 14
# HIP14237
# getting sample data...
# finished getting sample data
# 15
# HIP14240
# getting sample data...
# finished getting sample data
# 16
# HIP11717
# getting sample data...
# finished getting sample data
# 17
# HIP11784
# getting sample data...
# finished getting sample data
# 18
# HIP02663
# getting sample data...
# finished getting sample data
# 19
# HIP13939
# getting sample data...
# finished getting sample data
# 20
# HIP14911
# getting sample data...
# finished getting sample data
# 21
# HIP02805
# getting sample data...
# finished getting sample data
# 22
# HIP13318
# getting sample data...
# finished getting sample data
# 23
# HIP19048
# getting sample data...
# finished getting sample data
# 24
# HIP05398
# getting sample data...
# finished getting sample data
# 25
# HIP04480
# getting sample data...
# finished getting sample data
# 26
# HIP13722
# getting sample data...
# finished getting sample data
# 27
# HIP13658
# getting sample data...
# finished getting sample data
# 28
# HIP13185
# getting sample data...
# finished getting sample data
# 29
# HIP03597
# getting sample data...
# finished getting sample data
# 30
# HIP12703
# getting sample data...
# finished getting sample data
# 31
# HIP14205
# getting sample data...
# finished getting sample data
# 32
# HIP13976
# getting sample data...
# finished getting sample data
# 33
# HIP05535
# getting sample data...
# finished getting sample data
# 34
# HIP18119
# getting sample data...
# finished getting sample data
# 35
# HIP13806
# getting sample data...
# finished getting sample data
# 36
# HIP13992
# getting sample data...
# finished getting sample data
# 37
# HIP13871
# getting sample data...
# finished getting sample data
# 38
# HIP08821
# getting sample data...
# finished getting sample data
# 39
# HIP08598
# getting sample data...
# finished getting sample data
# 40
# HIP11758
# getting sample data...
# finished getting sample data
# 41
# HIP01181
# getting sample data...
# finished getting sample data
# 42
# HIP00707
# getting sample data...
# finished getting sample data
# 43
# HIP14127
# getting sample data...
# finished getting sample data
# 44
# HIP13703
# getting sample data...
# finished getting sample data
# 45
# HIP13774
# getting sample data...
# finished getting sample data
# 46
# HIP12088
# getting sample data...
# finished getting sample data
# 47
# HIP03216
# getting sample data...
# finished getting sample data
# 48
# HIP13709
# getting sample data...
# finished getting sample data
# 49
# HIP11857
# getting sample data...
# finished getting sample data
# 50
# HIP03651
# getting sample data...
# finished getting sample data
# 51
# HIP14020
# getting sample data...
# finished getting sample data
# 52
# HIP06191
# getting sample data...
# finished getting sample data
# 53
# HIP01266
# getting sample data...
# finished getting sample data
# 54
# HIP00924
# getting sample data...
# finished getting sample data
# 55
# HIP15861
# getting sample data...
# finished getting sample data
# 56
# HIP13920
# getting sample data...
# finished getting sample data
# 57
# HIP05563
# getting sample data...
# finished getting sample data
# 58
# HIP09190
# getting sample data...
# finished getting sample data
# 59
# HIP13746
# getting sample data...
# finished getting sample data
# 60
# HIP14018
# getting sample data...
# finished getting sample data
# 61
# HIP13376
# getting sample data...
# finished getting sample data
# 62
# HIP13636
# getting sample data...
# finished getting sample data
# 63
# HIP09097
# getting sample data...
# finished getting sample data
# 64
# HIP01223
# getting sample data...
# finished getting sample data
# 65
# HIP00985
# getting sample data...
# finished getting sample data
# 66
# HIP13981
# getting sample data...
# finished getting sample data
# 67
# HIP10564
# getting sample data...
# finished getting sample data
# 68
# HIP05551
# getting sample data...
# finished getting sample data
# 69
# HIP13178
# getting sample data...
# finished getting sample data
# 70
# HIP01253
# getting sample data...
# finished getting sample data
# 71
# HIP03484
# getting sample data...
# finished getting sample data
# 72
# HIP13865
# getting sample data...
# finished getting sample data
# 73
# HIP13986
# getting sample data...
# finished getting sample data
# 74
# HIP10480
# getting sample data...
# finished getting sample data
# 75
# HIP10514
# getting sample data...
# finished getting sample data
# 76
# HIP13818
# getting sample data...
# finished getting sample data
# 77
# HIP17793
# getting sample data...
# finished getting sample data
# 78
# HIP13962
# getting sample data...
# finished getting sample data
# 79
# HIP02742
# getting sample data...
# finished getting sample data
# 80
# HIP15854
# getting sample data...
# finished getting sample data
# 81
# HIP08711
# getting sample data...
# finished getting sample data
# 82
# HIP12129
# getting sample data...
# finished getting sample data
# 83
# HIP13736
# getting sample data...
# finished getting sample data
# 84
# HIP13741
# getting sample data...
# finished getting sample data
# 85
# HIP13306
# getting sample data...
# finished getting sample data
# 86
# HIP14118
# getting sample data...
# finished getting sample data
# 87
# HIP14015
# getting sample data...
# finished getting sample data
# 88
# HIP14181
# getting sample data...
# finished getting sample data
# 89
# HIP12123
# getting sample data...
# finished getting sample data
# 90
# HIP02811
# getting sample data...
# finished getting sample data
# 91
# HIP09235
# getting sample data...
# finished getting sample data
# 92
# HIP14223
# getting sample data...
# finished getting sample data
# 93
# HIP11774
# getting sample data...
# finished getting sample data
# 94
# HIP09775
# getting sample data...
# finished getting sample data
# 95
# HIP08977
# getting sample data...
# finished getting sample data
# 96
# HIP14157
# getting sample data...
# finished getting sample data
# 97
# HIP00777
# getting sample data...
# finished getting sample data
# 98
# HIP04545
# getting sample data...
# finished getting sample data
# 99
# HIP04532
# getting sample data...
# finished getting sample data
# 100
# HIP09046
# getting sample data...
# finished getting sample data
# 101
# HIP03385
# getting sample data...
# finished getting sample data
# 102
# HIP01805
# getting sample data...
# finished getting sample data
# 103
# HIP08653
# getting sample data...
# finished getting sample data
# 104
# HIP01162
# getting sample data...
# finished getting sample data
# 105
# HIP13233
# getting sample data...
# finished getting sample data
# 106
# HIP13244
# getting sample data...
# finished getting sample data
# 107
# HIP14202
# getting sample data...
# finished getting sample data
# 108
# HIP09364
# getting sample data...
# finished getting sample data
# 109
# HIP10507
# getting sample data...
# finished getting sample data
# 110
# HIP00805
# getting sample data...
# finished getting sample data
# 111
# HIP02875
# getting sample data...
# finished getting sample data
# 112
# HIP14192
# getting sample data...
# finished getting sample data
# 113
# HIP14071
# getting sample data...
# finished getting sample data
# 114
# HIP02112
# getting sample data...
# finished getting sample data
# 115
# HIP13265
# getting sample data...
# finished getting sample data
# 116
# HIP03677
# getting sample data...
# finished getting sample data
# 117
# HIP16738
# getting sample data...
# finished getting sample data
# 118
# HIP14176
# getting sample data...
# finished getting sample data
# 119
# HIP14095
# getting sample data...
# finished getting sample data
# 120
# HIP03693
# getting sample data...
# finished getting sample data
# 121
# HIP08702
# getting sample data...
# finished getting sample data
# 122
# HIP17837
# getting sample data...
# finished getting sample data
# 123
# HIP01597
# getting sample data...
# finished getting sample data
# 124
# HIP10445
# getting sample data...
# finished getting sample data
# 125
# HIP13414
# getting sample data...
# finished getting sample data
# 126
# HIP14230
# getting sample data...
# finished getting sample data
# 127
# HIP01391
# getting sample data...
# finished getting sample data
# 128
# HIP08439
# getting sample data...
# finished getting sample data
# 129
# HIP13949
# getting sample data...
# finished getting sample data
# 130
# HIP13833
# getting sample data...
# finished getting sample data
# 131
# HIP13220
# getting sample data...
# finished getting sample data
# 132
# HIP14043
# getting sample data...
# finished getting sample data
# 133
# HIP14034
# getting sample data...
# finished getting sample data
# 134
# HIP00614
# getting sample data...
# finished getting sample data
# 135
# HIP03378
# getting sample data...
# finished getting sample data
# 136
# HIP13610
# getting sample data...
# finished getting sample data
# 137
# HIP03275
# getting sample data...
# finished getting sample data
# 138
# HIP09022
# getting sample data...
# finished getting sample data
# 139
# HIP13760
# getting sample data...
# finished getting sample data
# 140
# HIP10746
# getting sample data...
# finished getting sample data
# 141
# HIP13350
# getting sample data...
# finished getting sample data
# 142
# HIP12538
# getting sample data...
# finished getting sample data
# 143
# HIP10376
# getting sample data...
# finished getting sample data
# 144
# HIP08399
# getting sample data...
# finished getting sample data
# 145
# HIP01298
# getting sample data...
# finished getting sample data
# 146
# HIP11613
# getting sample data...
# finished getting sample data
# 147
# HIP14243
# getting sample data...
# finished getting sample data
# 148
# HIP00934
# getting sample data...
# finished getting sample data
# 149
# HIP14234
# getting sample data...
# finished getting sample data
# 150
# HIP05409
# getting sample data...
# finished getting sample data
# 151
# HIP13947
# getting sample data...
# finished getting sample data
# 152
# HIP13489
# getting sample data...
# finished getting sample data
# 153
# HIP14140
# getting sample data...
# finished getting sample data
# 154
# HIP04552
# getting sample data...
# finished getting sample data
# 155
# HIP11937
# getting sample data...
# finished getting sample data
# 156
# HIP03746
# getting sample data...
# finished getting sample data
# 157
# HIP13764
# getting sample data...
# finished getting sample data
# 158
# HIP09026
# getting sample data...
# finished getting sample data
# 159
# HIP09051
# getting sample data...
# finished getting sample data
# 160
# HIP13663
# getting sample data...
# finished getting sample data
# 161
# HIP14030
# getting sample data...
# finished getting sample data
# 162
# HIP00898
# getting sample data...
# finished getting sample data
# 163
# HIP10823
# getting sample data...
# finished getting sample data
# 164
# HIP01797
# getting sample data...
# finished getting sample data
# 165
# HIP17760
# getting sample data...
# finished getting sample data
# 166
# HIP13902
# getting sample data...
# finished getting sample data
# 167
# HIP13975
# getting sample data...
# finished getting sample data
# 168
# HIP14206
# getting sample data...
# finished getting sample data
# 169
# HIP00971
# getting sample data...
# finished getting sample data
# 170
# HIP09119
# getting sample data...
# finished getting sample data
# 171
# HIP01470
# getting sample data...
# finished getting sample data
# 172
# HIP13311
# getting sample data...
# finished getting sample data
# 173
# HIP14172
# getting sample data...
# finished getting sample data
# 174
# HIP14196
# getting sample data...
# finished getting sample data
# 175
# HIP01820
# getting sample data...
# finished getting sample data
# 176
# HIP12143
# getting sample data...
# finished getting sample data
# 177
# HIP13954
# getting sample data...
# finished getting sample data
# 178
# HIP13859
# getting sample data...
# finished getting sample data
# 179
# HIP08890
# getting sample data...
# finished getting sample data
# 180
# HIP01218
# getting sample data...
# finished getting sample data
# 181
# HIP14227
# getting sample data...
# finished getting sample data
# 182
# HIP13929
# getting sample data...
# finished getting sample data
# 183
# HIP13853
# getting sample data...
# finished getting sample data
# 184
# HIP05467
# getting sample data...
# finished getting sample data
# 185
# HIP02790
# getting sample data...
# finished getting sample data
# 186
# HIP03381
# getting sample data...
# finished getting sample data
# 187
# HIP10726
# getting sample data...
# finished getting sample data
# 188
# HIP13777
# getting sample data...
# finished getting sample data
# 189
# HIP00773
# getting sample data...
# finished getting sample data
# 190
# HIP14124
# getting sample data...
# finished getting sample data
# 191
# HIP14153
# getting sample data...
# finished getting sample data
# 192
# HIP05552
# getting sample data...
# finished getting sample data
# 193
# HIP13966
# getting sample data...
# finished getting sample data
# 194
# HIP13988
# getting sample data...
# finished getting sample data
# 195
# HIP19716
# getting sample data...
# finished getting sample data
# 196
# HIP05455
# getting sample data...
# finished getting sample data
# 197
# HIP02271
# getting sample data...
# finished getting sample data
# 198
# HIP01220
# getting sample data...
# finished getting sample data
# 199
# HIP10787
# getting sample data...
# finished getting sample data
# 200
# HIP05388
# getting sample data...
# finished getting sample data
# 201
# HIP04597
# getting sample data...
# finished getting sample data
# 202
# HIP14161
# getting sample data...
# finished getting sample data
# 203
# HIP17577
# getting sample data...
# finished getting sample data
# 204
# HIP13396
# getting sample data...
# finished getting sample data
# 205
# HIP04509
# getting sample data...
# finished getting sample data
# 206
# HIP14016
# getting sample data...
# finished getting sample data
# 207
# HIP02078
# getting sample data...
# finished getting sample data
# 208
# HIP13291
# getting sample data...
# finished getting sample data
# 209
# HIP02962
# getting sample data...
# finished getting sample data
# 210
# HIP10669
# getting sample data...
# finished getting sample data
# 211
# HIP13961
# getting sample data...
# finished getting sample data
# 212
# HIP13916
# getting sample data...
# finished getting sample data
# 213
# HIP14218
# getting sample data...
# finished getting sample data
# 214
# HIP13198
# getting sample data...
# finished getting sample data
# 215
# HIP13176
# getting sample data...
# finished getting sample data
# 216
# HIP14129
# getting sample data...
# finished getting sample data
# 217
# HIP14053
# getting sample data...
# finished getting sample data
# 218
# HIP02820
# getting sample data...
# finished getting sample data
# 219
# HIP12165
# getting sample data...
# finished getting sample data
# 220
# HIP13699
# getting sample data...
# finished getting sample data
# 221
# HIP17445
# getting sample data...
# finished getting sample data
# 222
# HIP13794
# getting sample data...
# finished getting sample data
# 223
# HIP14844
# getting sample data...
# finished getting sample data
# 224
# HIP08389
# getting sample data...
# finished getting sample data
# 225
# HIP14059
# getting sample data...
# finished getting sample data
# 226
# HIP19089
# getting sample data...
# finished getting sample data
# 227
# HIP13473
# getting sample data...
# finished getting sample data
# 228
# HIP00594
# getting sample data...
# finished getting sample data
# 229
# HIP05460
# getting sample data...
# finished getting sample data
# 230
# HIP13854
# getting sample data...
# finished getting sample data
# 231
# HIP13823
# getting sample data...
# finished getting sample data
# 232
# HIP03111
# getting sample data...
# finished getting sample data
# 233
# HIP13497
# getting sample data...
# finished getting sample data
# 234
# HIP01499
# getting sample data...
# finished getting sample data
# 235
# HIP13751
# getting sample data...
# finished getting sample data
# 236
# HIP10694
# getting sample data...
# finished getting sample data
# 237
# HIP12034
# getting sample data...
# finished getting sample data
# 238
# HIP13361
# getting sample data...
# finished getting sample data
# 239
# HIP09559
# getting sample data...
# finished getting sample data
# 240
# HIP08346
# getting sample data...
# finished getting sample data
# 241
# HIP04510
# getting sample data...
# finished getting sample data
# 242
# HIP14175
# getting sample data...
# finished getting sample data
# 243
# HIP01140
# getting sample data...
# finished getting sample data
# 244
# HIP00728
# getting sample data...
# finished getting sample data
# 245
# HIP14072
# getting sample data...
# finished getting sample data
# 246
# HIP08236
# getting sample data...
# finished getting sample data
# 247
# HIP01850
# getting sample data...
# finished getting sample data
# 248
# HIP03233
# getting sample data...
# finished getting sample data
# 249
# HIP08792
# getting sample data...
# finished getting sample data
# 250
# HIP13978
# getting sample data...
# finished getting sample data
# 251
# HIP13875
# getting sample data...
# finished getting sample data
# 252
# HIP08596
# getting sample data...
# finished getting sample data
# 253
# HIP10597
# getting sample data...
# finished getting sample data
# 254
# HIP13972
# getting sample data...
# finished getting sample data
# 255
# HIP09284
# getting sample data...
# finished getting sample data
# 256
# HIP13015
# getting sample data...
# finished getting sample data
# 257
# HIP02024
# getting sample data...
# finished getting sample data
# 258
# HIP04555
# getting sample data...
# finished getting sample data
# 259
# HIP14130
# getting sample data...
# finished getting sample data
# 260
# HIP13324
# getting sample data...
# finished getting sample data
# 261
# HIP14494
# getting sample data...
# finished getting sample data
# 262
# HIP13769
# getting sample data...
# finished getting sample data
# 263
# HIP14037
# getting sample data...
# finished getting sample data
# 264
# HIP01091
# getting sample data...
# finished getting sample data
# 265
# HIP13847
# getting sample data...
# finished getting sample data
# 266
# HIP05590
# getting sample data...
# finished getting sample data
# 267
# HIP03812
# getting sample data...
# finished getting sample data
# 268
# HIP13157
# getting sample data...
# finished getting sample data
# 269
# HIP01206
# getting sample data...
# finished getting sample data
# 270
# HIP01392
# getting sample data...
# finished getting sample data
# 271
# HIP14244
# getting sample data...
# finished getting sample data
# 272
# HIP05574
# getting sample data...
# finished getting sample data
# 273
# HIP08989
# getting sample data...
# finished getting sample data
# 274
# HIP03502
# getting sample data...
# finished getting sample data
# 275
# HIP14209
# getting sample data...
# finished getting sample data
# 276
# HIP13994
# getting sample data...
# finished getting sample data
# 277
# HIP05434
# getting sample data...
# finished getting sample data
# 278
# HIP13877
# getting sample data...
# finished getting sample data
# 279
# HIP08827
# getting sample data...
# finished getting sample data
# 280
# HIP08507
# getting sample data...
# finished getting sample data
# 281
# HIP09365
# getting sample data...
# finished getting sample data
# 282
# HIP05533
# getting sample data...
# finished getting sample data
# 283
# HIP13893
# getting sample data...
# finished getting sample data
# 284
# HIP13427
# getting sample data...
# finished getting sample data
# 285
# HIP01798
# getting sample data...
# finished getting sample data
# 286
# HIP08400
# getting sample data...
# finished getting sample data
# 287
# HIP08499
# getting sample data...
# finished getting sample data
# 288
# HIP00169
# getting sample data...
# finished getting sample data
# 289
# HIP03591
# getting sample data...
# finished getting sample data
# 290
# HIP13183
# getting sample data...
# finished getting sample data
# 291
# HIP04611
# getting sample data...
# finished getting sample data
# 292
# HIP01596
# getting sample data...
# finished getting sample data
# 293
# HIP13363
# getting sample data...
# finished getting sample data
# 294
# HIP08339
# getting sample data...
# finished getting sample data
# 295
# HIP14007
# getting sample data...
# finished getting sample data
# 296
# HIP02997
# getting sample data...
# finished getting sample data
# 297
# HIP17585
# getting sample data...
# finished getting sample data
# 298
# HIP10814
# getting sample data...
# finished getting sample data
# 299
# HIP13122
# getting sample data...
# finished getting sample data
# 300
# HIP14231
# getting sample data...
# finished getting sample data
# 301
# HIP09789
# getting sample data...
# finished getting sample data
# 302
# HIP11711
# getting sample data...
# finished getting sample data
# 303
# HIP13935
# getting sample data...
# finished getting sample data
# 304
# HIP13518
# getting sample data...
# finished getting sample data
# 305
# HIP14048
# getting sample data...
# finished getting sample data
# 306
# HIP10377
# getting sample data...
# finished getting sample data
# 307
# HIP09159
# getting sample data...
# finished getting sample data
# 308
# HIP10730
# getting sample data...
# finished getting sample data
# 309
# HIP09029
# getting sample data...
# finished getting sample data
# 310
# HIP17454
# getting sample data...
# finished getting sample data
# 311
# HIP12097
# getting sample data...
# finished getting sample data
# 312
# HIP13256
# getting sample data...
# finished getting sample data
# 313
# HIP12533
# getting sample data...
# finished getting sample data
# 314
# HIP14138
# getting sample data...
# finished getting sample data
# 315
# HIP15855
# getting sample data...
# finished getting sample data
# 316
# HIP01765
# getting sample data...
# finished getting sample data
# 317
# HIP13880
# getting sample data...
# finished getting sample data
# 318
# HIP10568
# getting sample data...
# finished getting sample data
# 319
# HIP02734
# getting sample data...
# finished getting sample data
# 320
# HIP13449
# getting sample data...
# finished getting sample data
# 321
# HIP13987
# getting sample data...
# finished getting sample data
# 322
# HIP03511
# getting sample data...
# finished getting sample data
# 323
# HIP01836
# getting sample data...
# finished getting sample data
# 324
# HIP04471
# getting sample data...
# finished getting sample data
# 325
# HIP14014
# getting sample data...
# finished getting sample data
# 326
# HIP04576
# getting sample data...
# finished getting sample data
# 327
# HIP03618
# getting sample data...
# finished getting sample data
# 328
# HIP13370
# getting sample data...
# finished getting sample data
# 329
# HIP08710
# getting sample data...
# finished getting sample data
# 330
# HIP03228
# getting sample data...
# finished getting sample data
# 331
# HIP13926
# getting sample data...
# finished getting sample data
# 332
# HIP09344
# getting sample data...
# finished getting sample data
# 333
# HIP13951
# getting sample data...
# finished getting sample data
# 334
# HIP00825
# getting sample data...
# finished getting sample data
# 335
# HIP05838
# getting sample data...
# finished getting sample data
# 336
# HIP13856
# getting sample data...
# finished getting sample data
# 337
# HIP05942
# getting sample data...
# finished getting sample data
# 338
# HIP13245
# getting sample data...
# finished getting sample data
# 339
# HIP14051
# getting sample data...
# finished getting sample data
# 340
# HIP13796
# getting sample data...
# finished getting sample data
# 341
# HIP02855
# getting sample data...
# finished getting sample data
# 342
# HIP14156
# getting sample data...
# finished getting sample data
# 343
# HIP14121
# getting sample data...
# finished getting sample data
# 344
# HIP12527
# getting sample data...
# finished getting sample data
# 345
# HIP17440
# getting sample data...
# finished getting sample data
# 346
# HIP03383
# getting sample data...
# finished getting sample data
# 347
# HIP02928
# getting sample data...
# finished getting sample data
# 348
# HIP08725
# getting sample data...
# finished getting sample data
# 349
# HIP01180
# getting sample data...
# finished getting sample data
# 350
# HIP03720
# getting sample data...
# finished getting sample data
# 351
# HIP00771
# getting sample data...
# finished getting sample data
# 352
# HIP12900
# getting sample data...
# finished getting sample data
# 353
# HIP13956
# getting sample data...
# finished getting sample data
# 354
# HIP00822
# getting sample data...
# finished getting sample data
# 355
# HIP01384
# getting sample data...
# finished getting sample data
# 356
# HIP08521
# getting sample data...
# finished getting sample data
# 357
# HIP14187
# getting sample data...
# finished getting sample data
# 358
# HIP14064
# getting sample data...
# finished getting sample data
# 359
# HIP04498
# getting sample data...
# finished getting sample data
# 360
# HIP00734
# getting sample data...
# finished getting sample data
# 361
# HIP14114
# getting sample data...
# finished getting sample data
# 362
# HIP13294
# getting sample data...
# finished getting sample data
# 363
# HIP10716
# getting sample data...
# finished getting sample data
# 364
# HIP01582
# getting sample data...
# finished getting sample data
# 365
# HIP04605
# getting sample data...
# finished getting sample data
# 366
# HIP14217
# getting sample data...
# finished getting sample data
# 367
# HIP13887
# getting sample data...
# finished getting sample data
# 368
# HIP13964
# getting sample data...
# finished getting sample data
# 369
# HIP17698
# getting sample data...
# finished getting sample data
# 370
# HIP13869
# getting sample data...
# finished getting sample data
# 371
# HIP13919
# getting sample data...
# finished getting sample data
# 372
# HIP13814
# getting sample data...
# finished getting sample data
# 373
# HIP01255
# getting sample data...
# finished getting sample data
# 374
# HIP11518
# getting sample data...
# finished getting sample data
# 375
# HIP14142
# getting sample data...
# finished getting sample data
# 376
# HIP00715
# getting sample data...
# finished getting sample data
# 377
# HIP04527
# getting sample data...
# finished getting sample data
# 378
# HIP13766
# getting sample data...
# finished getting sample data
# 379
# HIP02931
# getting sample data...
# finished getting sample data
# 380
# HIP11058
# getting sample data...
# finished getting sample data
# 381
# HIP13782
# getting sample data...
# finished getting sample data
# 382
# HIP13661
# getting sample data...
# finished getting sample data
# 383
# HIP14148
# getting sample data...
# finished getting sample data
# 384
# HIP02126
# getting sample data...
# finished getting sample data
# 385
# HIP12980
# getting sample data...
# finished getting sample data
# 386
# HIP14045
# getting sample data...
# finished getting sample data
# 387
# HIP12534
# getting sample data...
# finished getting sample data
# 388
# HIP08986
# getting sample data...
# finished getting sample data
# 389
# HIP03107
# getting sample data...
# finished getting sample data
# 390
# HIP05595
# getting sample data...
# finished getting sample data
# 391
# HIP13515
# getting sample data...
# finished getting sample data
# 392
# HIP10443
# getting sample data...
# finished getting sample data
# 393
# HIP13848
# getting sample data...
# finished getting sample data
# 394
# HIP17657
# getting sample data...
# finished getting sample data
# 395
# HIP03099
# getting sample data...
# finished getting sample data
# 396
# HIP13945
# getting sample data...
# finished getting sample data
# 397
# HIP03194
# getting sample data...
# finished getting sample data
# 398
# HIP13754
# getting sample data...
# finished getting sample data
# 399
# HIP14170
# getting sample data...
# finished getting sample data
# 400
# HIP14107
# getting sample data...
# finished getting sample data
# 401
# HIP14194
# getting sample data...
# finished getting sample data
# 402
# HIP14000
# getting sample data...
# finished getting sample data
# 403
# HIP14077
# getting sample data...
# finished getting sample data
# 404
# HIP13319
# getting sample data...
# finished getting sample data
# 405
# HIP05377
# getting sample data...
# finished getting sample data
# 406
# HIP13263
# getting sample data...
# finished getting sample data
# 407
# HIP13214
# getting sample data...
# finished getting sample data
# 408
# HIP10602
# getting sample data...
# finished getting sample data
# 409
# HIP02873
# getting sample data...
# finished getting sample data
# 410
# HIP03236
# getting sample data...
# finished getting sample data
# 411
# HIP03505
# getting sample data...
# finished getting sample data
# 412
# HIP05444
# getting sample data...
# finished getting sample data
# 413
# HIP01795
# getting sample data...
# finished getting sample data
# 414
# HIP10821
# getting sample data...
# finished getting sample data
# 415
# HIP13894
# getting sample data...
# finished getting sample data
# 416
# HIP13900
# getting sample data...
# finished getting sample data
# 417
# HIP00904
# getting sample data...
# finished getting sample data
# 418
# HIP16867
# getting sample data...
# finished getting sample data
# 419
# HIP01571
# getting sample data...
# finished getting sample data
# 420
# HIP02877
# getting sample data...
# finished getting sample data
# 421
# HIP11553
# getting sample data...
# finished getting sample data
# 422
# HIP14004
# getting sample data...
# finished getting sample data
# 423
# HIP14109
# getting sample data...
# finished getting sample data
# 424
# HIP13360
# getting sample data...
# finished getting sample data
# 425
# HIP04511
# getting sample data...
# finished getting sample data
# 426
# HIP14079
# getting sample data...
# finished getting sample data
# 427
# HIP14174
# getting sample data...
# finished getting sample data
# 428
# HIP14103
# getting sample data...
# finished getting sample data
# 429
# HIP00999
# getting sample data...
# finished getting sample data
# 430
# HIP03592
# getting sample data...
# finished getting sample data
# 431
# HIP09366
# getting sample data...
# finished getting sample data
# 432
# HIP13809
# getting sample data...
# finished getting sample data
# 433
# HIP10408
# getting sample data...
# finished getting sample data
# 434
# HIP05960
# getting sample data...
# finished getting sample data
# 435
# HIP13554
# getting sample data...
# finished getting sample data
# 436
# HIP13803
# getting sample data...
# finished getting sample data
# 437
# HIP05437
# getting sample data...
# finished getting sample data
# 438
# HIP03495
# getting sample data...
# finished getting sample data
# 439
# HIP14036
# getting sample data...
# finished getting sample data
# 440
# HIP13786
# getting sample data...
# finished getting sample data
# 441
# HIP17457
# getting sample data...
# finished getting sample data
# 442
# HIP09150
# getting sample data...
# finished getting sample data
# 443
# HIP09020
# getting sample data...
# finished getting sample data
# 444
# HIP03370
# getting sample data...
# finished getting sample data
# 445
# HIP01197
# getting sample data...
# finished getting sample data
# 446
# HIP13228
# getting sample data...
# finished getting sample data
# 447
# HIP13352
# getting sample data...
# finished getting sample data
# 448
# HIP13325
# getting sample data...
# finished getting sample data
# 449
# HIP13941
# getting sample data...
# finished getting sample data
# 450
# HIP03004
# getting sample data...
# finished getting sample data
# 451
# HIP10447
# getting sample data...
# finished getting sample data
# 452
# HIP08076
# getting sample data...
# finished getting sample data
# 453
# HIP01393
# getting sample data...
# finished getting sample data
# 454
# HIP14238
# getting sample data...
# finished getting sample data
# 455
# HIP17723
# getting sample data...
# finished getting sample data
# 456
# HIP13511
# getting sample data...
# finished getting sample data
# 457
# HIP05405
# getting sample data...
# finished getting sample data
# 458
# HIP13831
# getting sample data...
# finished getting sample data
# 459
# HIP09253
# getting sample data...
# finished getting sample data
# 460
# HIP08816
# getting sample data...
# finished getting sample data
# 461
# HIP01465
# getting sample data...
# finished getting sample data
# 462
# HIP09001
# getting sample data...
# finished getting sample data
# 463
# HIP11989
# getting sample data...
# finished getting sample data
# 464
# HIP13209
# getting sample data...
# finished getting sample data
# 465
# HIP01055
# getting sample data...
# finished getting sample data
# 466
# HIP01022
# getting sample data...
# finished getting sample data
# 467
# HIP13274
# getting sample data...
# finished getting sample data
# 468
# HIP00640
# getting sample data...
# finished getting sample data
# 469
# HIP02103
# getting sample data...
# finished getting sample data
# 470
# HIP14183
# getting sample data...
# finished getting sample data
# 471
# HIP14060
# getting sample data...
# finished getting sample data
# 472
# HIP13749
# getting sample data...
# finished getting sample data
# 473
# HIP02737
# getting sample data...
# finished getting sample data
# 474
# HIP14213
# getting sample data...
# finished getting sample data
# 475
# HIP00869
# getting sample data...
# finished getting sample data
# 476
# HIP11649
# getting sample data...
# finished getting sample data
# 477
# HIP00775
# getting sample data...
# finished getting sample data
# 478
# HIP10389
# getting sample data...
# finished getting sample data
# 479
# HIP17534
# getting sample data...
# finished getting sample data
# 480
# HIP17887
# getting sample data...
# finished getting sample data
# 481
# HIP01870
# getting sample data...
# finished getting sample data
# 482
# HIP01160
# getting sample data...
# finished getting sample data
# 483
# HIP13822
# getting sample data...
# finished getting sample data
# 484
# HIP05941
# getting sample data...
# finished getting sample data
# 485
# HIP13958
# getting sample data...
# finished getting sample data
# 486
# HIP08805
# getting sample data...
# finished getting sample data
# 487
# HIP00826
# getting sample data...
# finished getting sample data
# 488
# HIP00851
# getting sample data...
# finished getting sample data
# 489
# HIP01313
# getting sample data...
# finished getting sample data
# 490
# HIP16515
# getting sample data...
# finished getting sample data
# 491
# HIP14221
# getting sample data...
# finished getting sample data
# 492
# HIP13505
# getting sample data...
# finished getting sample data
# 493
# HIP17737
# getting sample data...
# finished getting sample data
# 494
# HIP13928
# getting sample data...
# finished getting sample data
# 495
# HIP13852
# getting sample data...
# finished getting sample data
# 496
# HIP03807
# getting sample data...
# finished getting sample data
# 497
# HIP13142
# getting sample data...
# finished getting sample data
# 498
# HIP01264
# getting sample data...
# finished getting sample data
# 499
# HIP01219
# getting sample data...
# finished getting sample data
# 500
# HIP04634
# getting sample data...
# finished getting sample data
# 501
# HIP00926
# getting sample data...
# finished getting sample data
# 502
# HIP05561
# getting sample data...
# finished getting sample data
# 503
# HIP05841
# getting sample data...
# finished getting sample data
# 504
# HIP13402
# getting sample data...
# finished getting sample data
# 505
# HIP10424
# getting sample data...
# finished getting sample data
# 506
# HIP08972
# getting sample data...
# finished getting sample data
# 507
# HIP14028
# getting sample data...
# finished getting sample data
# 508
# HIP14152
# getting sample data...
# finished getting sample data
# 509
# HIP17449
# getting sample data...
# finished getting sample data
# 510
# HIP13671
# getting sample data...
# finished getting sample data
# 511
# HIP14055
# getting sample data...
# finished getting sample data
# 512
# HIP00602
# getting sample data...
# finished getting sample data
# 513
# HIP00813
# getting sample data...
# finished getting sample data
# 514
# HIP10846
# getting sample data...
# finished getting sample data
# 515
# HIP05559
# getting sample data...
# finished getting sample data
# 516
# HIP03125
# getting sample data...
# finished getting sample data
# 517
# HIP13983
# getting sample data...
# finished getting sample data
# 518
# HIP13860
# getting sample data...
# finished getting sample data
# 519
# HIP13967
# getting sample data...
# finished getting sample data
# 520
# HIP05524
# getting sample data...
# finished getting sample data
# 521
# HIP19717
# getting sample data...
# finished getting sample data
# 522
# HIP13989
# getting sample data...
# finished getting sample data
# 523
# HIP00819
# getting sample data...
# finished getting sample data
# 524
# HIP14214
# getting sample data...
# finished getting sample data
# 525
# HIP13303
# getting sample data...
# finished getting sample data
# 526
# HIP14160
# getting sample data...
# finished getting sample data
# 527
# HIP13309
# getting sample data...
# finished getting sample data
# 528
# HIP14184
# getting sample data...
# finished getting sample data
# 529
# HIP04578
# getting sample data...
# finished getting sample data
# 530
# HIP10358
# getting sample data...
# finished getting sample data
# 531
# HIP02090
# getting sample data...
# finished getting sample data
# 532
# HIP08223
# getting sample data...
# finished getting sample data
# 533
# HIP04475
# getting sample data...
# finished getting sample data
# 534
# HIP05757
# getting sample data...
# finished getting sample data
# 535
# HIP03197
# getting sample data...
# finished getting sample data
# 536
# HIP00838
# getting sample data...
# finished getting sample data
# 537
# HIP03814
# getting sample data...
# finished getting sample data
# 538
# HIP00832
# getting sample data...
# finished getting sample data
# 539
# HIP05578
# getting sample data...
# finished getting sample data
# 540
# HIP08888
# getting sample data...
# finished getting sample data
# 541
# HIP05331
# getting sample data...
# finished getting sample data
# 542
# HIP13252
# getting sample data...
# finished getting sample data
# 543
# HIP02848
# getting sample data...
# finished getting sample data
# 544
# HIP10639
# getting sample data...
# finished getting sample data
# 545
# HIP12099
# getting sample data...
# finished getting sample data
# 546
# HIP13686
# getting sample data...
# finished getting sample data
# 547
# HIP14136
# getting sample data...
# finished getting sample data
# 548
# HIP08305
# getting sample data...
# finished getting sample data
# 549
# HIP00761
# getting sample data...
# finished getting sample data
# 550
# HIP13355
# getting sample data...
# finished getting sample data
# 551
# HIP01004
# getting sample data...
# finished getting sample data
# 552
# HIP05817
# getting sample data...
# finished getting sample data
# 553
# HIP05540
# getting sample data...
# finished getting sample data
# 554
# HIP13903
# getting sample data...
# finished getting sample data
# 555
# HIP00110
# getting sample data...
# finished getting sample data
# 556
# HIP01232
# getting sample data...
# finished getting sample data
# 557
# HIP13627
# getting sample data...
# finished getting sample data
# 558
# HIP17462
# getting sample data...
# finished getting sample data
# 559
# HIP01856
# getting sample data...
# finished getting sample data
# 560
# HIP13217
# getting sample data...
# finished getting sample data
# 561
# HIP15685
# getting sample data...
# finished getting sample data
# 562
# HIP08230
# getting sample data...
# finished getting sample data
# 563
# HIP14074
# getting sample data...
# finished getting sample data
# 564
# HIP03678
# getting sample data...
# finished getting sample data
# 565
# HIP05390
# getting sample data...
# finished getting sample data
# 566
# HIP14090
# getting sample data...
# finished getting sample data
# 567
# HIP14009
# getting sample data...
# finished getting sample data
# 568
# HIP08337
# getting sample data...
# finished getting sample data
# 569
# HIP13757
# getting sample data...
# finished getting sample data
# 570
# HIP09118
# getting sample data...
# finished getting sample data
# 571
# HIP13720
# getting sample data...
# finished getting sample data
# 572
# HIP17845
# getting sample data...
# finished getting sample data
# 573
# HIP09062
# getting sample data...
# finished getting sample data

# %%
length_res_df.head()
# Out:
#           mean_cdr3_df_0  mean_cdr3_df_1  sv_cdr3_df_0  sv_cdr3_df_1  \
# Sample
# HIP11513       43.385221       45.934334      0.130826      0.172656
# HIP08200       43.562298       45.464928      0.123093      0.163256
# HIP00769       43.391093       45.848462      0.123096      0.169268
# HIP09122       43.389689       46.240361      0.119684      0.161508
# HIP12091             NaN             NaN           NaN           NaN
#
#           mean_vDeletion_df_0  mean_vDeletion_df_1  sv_vDeletion_df_0  \
# Sample
# HIP11513             3.634975             4.175824           0.705530
# HIP08200             3.602697             4.108244           0.705188
# HIP00769             3.685102             4.308395           0.683236
# HIP09122             3.622988             4.040173           0.692352
# HIP12091                  NaN                  NaN                NaN
#
#           sv_vDeletion_df_1  mean_n1Insertion_df_0  mean_n1Insertion_df_1  \
# Sample
# HIP11513           0.806018               4.042245               5.315776
# HIP08200           0.786793               4.027921               5.096850
# HIP00769           0.794575               4.075939               5.421017
# HIP09122           0.790408               3.869818               5.260260
# HIP12091                NaN                    NaN                    NaN
#
#                 ...          sv_d3Deletion_df_0  sv_d3Deletion_df_1  \
# Sample          ...
# HIP11513        ...                    0.803126            0.794909
# HIP08200        ...                    0.821048            0.819512
# HIP00769        ...                    0.802036            0.807135
# HIP09122        ...                    0.797379            0.789556
# HIP12091        ...                         NaN                 NaN
#
#           mean_n2Insertion_df_0  mean_n2Insertion_df_1  sv_n2Insertion_df_0  \
# Sample
# HIP11513               3.662580               4.840777             0.908867
# HIP08200               3.781941               4.863150             0.902893
# HIP00769               3.872001               5.295025             0.913831
# HIP09122               3.604046               4.923321             0.901971
# HIP12091                    NaN                    NaN                  NaN
#
#           sv_n2Insertion_df_1  mean_jDeletion_df_0  mean_jDeletion_df_1  \
# Sample
# HIP11513             0.877362             4.087003             4.104222
# HIP08200             0.878164             4.329462             4.448651
# HIP00769             0.877708             4.379503             4.575456
# HIP09122             0.865636             4.181189             4.142580
# HIP12091                  NaN                  NaN                  NaN
#
#           sv_jDeletion_df_0  sv_jDeletion_df_1
# Sample
# HIP11513           0.744285           0.815171
# HIP08200           0.759047           0.832477
# HIP00769           0.765565           0.827889
# HIP09122           0.750595           0.824729
# HIP12091                NaN                NaN
#
# [5 rows x 28 columns]
